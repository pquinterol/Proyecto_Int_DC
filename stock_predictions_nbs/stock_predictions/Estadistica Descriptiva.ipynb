# %%
# Librerias
import sys

# %%
# Accion Wells Fargo
tickerSymbol = "WFC"

# Rango de fecha
startDate = '2018-05-15' #  strings
endDate = '2023-05-15' #  strings

# %%
# Check if local computer has the library yfinance. If not, install. Then Import it.
# !{sys.executable} -m pip install yfinance # Check if the machine has yfinance, if not, download yfinance
import yfinance as yf # Import library to access Yahoo finance stock data
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# Crear ticker yfinance accion
tickerData = yf.Ticker(tickerSymbol)

# Creacion del DataFrame
df = tickerData.history(start = startDate, end = endDate)


print('-----------------------')
print('Done!')
print(df.head())
# Out:
# -----------------------
# Done!
#                                 Open       High        Low      Close  \
# Date
# 2022-05-16 00:00:00-04:00  41.252798  41.515489  40.571736  41.067936
# 2022-05-17 00:00:00-04:00  41.826831  42.634372  41.797640  42.527348
# 2022-05-18 00:00:00-04:00  42.118712  42.138171  40.756590  40.970638
# 2022-05-19 00:00:00-04:00  40.571735  41.165231  40.445251  40.863617
# 2022-05-20 00:00:00-04:00  41.359818  41.632244  39.637711  40.542545
#
#                              Volume  Dividends  Stock Splits
# Date
# 2022-05-16 00:00:00-04:00  16837400        0.0           0.0
# 2022-05-17 00:00:00-04:00  23340500        0.0           0.0
# 2022-05-18 00:00:00-04:00  27351300        0.0           0.0
# 2022-05-19 00:00:00-04:00  25211900        0.0           0.0
# 2022-05-20 00:00:00-04:00  35410400        0.0           0.0

# %%
df.describe()
# Out:
#              Open        High         Low       Close        Volume  \
# count  250.000000  250.000000  250.000000  250.000000  2.500000e+02
# mean    42.153601   42.691104   41.619244   42.163974  2.054114e+07
# std      3.021173    2.983357    3.071756    3.047602  9.248720e+06
# min     35.720570   36.196843   34.976391   35.948784  4.913300e+06
# 25%     39.754386   40.306461   39.000376   39.661723  1.481915e+07
# 50%     42.240331   42.726546   41.605238   42.242977  1.829540e+07
# 75%     44.637268   44.985329   43.990705   44.515164  2.331478e+07
# max     48.093779   48.460908   47.379368   48.123547  7.880690e+07
#
#         Dividends  Stock Splits
# count  250.000000         250.0
# mean     0.004800           0.0
# std      0.037718           0.0
# min      0.000000           0.0
# 25%      0.000000           0.0
# 50%      0.000000           0.0
# 75%      0.000000           0.0
# max      0.300000           0.0

# %%
import plotly.graph_objects as go

fig = go.Figure(data=[go.Candlestick(x=df.index[-30:],
                                    open=df['Open'][-30:],
                                    high=df['High'][-30:],
                                    low=df['Low'][-30:],
                                    close=df['Close'][-30:])])
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True)
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True)
fig.update_layout(title='Ultimos 30 dias WFC', yaxis_title='WFC usd')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 5))
df['Close'].hist(bins=30)
plt.title('Histograma Close WFC')
plt.show()

# %%
# Accion CHTR
tickerSymbol1 = "CHTR"

# Rango de fecha
startDate = '2018-05-15' #  strings
endDate = '2023-05-15' #  strings

# %%
# Crear ticker yfinance accion
tickerData = yf.Ticker(tickerSymbol1)

# Creacion del DataFrame
df_CHTR = tickerData.history(start = startDate, end = endDate)

# %%
df_CHTR.describe()
# Out:
#               Open         High          Low        Close        Volume  \
# count  1258.000000  1258.000000  1258.000000  1258.000000  1.258000e+03
# mean    484.786582   490.913665   478.958466   484.893656  1.240263e+06
# std     141.655937   142.817413   140.662076   141.590353  6.217578e+05
# min     261.700012   266.450012   259.480011   261.040009  4.064000e+05
# 25%     357.702492   360.832512   353.567505   357.057503  8.386250e+05
# 50%     468.794998   475.324997   463.434998   468.595001  1.090700e+06
# 75%     612.392487   619.544998   606.445007   612.492523  1.420675e+06
# max     823.080017   825.619995   817.530029   821.010010  5.720000e+06
#
#        Dividends  Stock Splits
# count     1258.0        1258.0
# mean         0.0           0.0
# std          0.0           0.0
# min          0.0           0.0
# 25%          0.0           0.0
# 50%          0.0           0.0
# 75%          0.0           0.0
# max          0.0           0.0

# %%
import plotly.graph_objects as go

fig = go.Figure(data=[go.Candlestick(x=df_CHTR.index[-30:],
                                    open=df_CHTR['Open'][-30:],
                                    high=df_CHTR['High'][-30:],
                                    low=df_CHTR['Low'][-30:],
                                    close=df_CHTR['Close'][-30:])])
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True)
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True)
fig.update_layout(title='Ultimos 30 dias CHTR', yaxis_title='CHTR usd')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 5))
df_CHTR['Close'].hist(bins=30)
plt.title('Histograma Close CHTR')
plt.show()

# %%
# Accion CHTR
tickerSymbol2 = "FFIV"

# Rango de fecha
startDate = '2018-05-15' #  strings
endDate = '2023-05-15' #  strings

# %%
# Crear ticker yfinance accion
tickerData = yf.Ticker(tickerSymbol2)

# Creacion del DataFrame
df_FFIV = tickerData.history(start = startDate, end = endDate)

# %%
df_FFIV.describe()
# Out:
#               Open         High          Low        Close        Volume  \
# count  1258.000000  1258.000000  1258.000000  1258.000000  1.258000e+03
# mean    164.419666   166.377536   162.394698   164.449173  6.485159e+05
# std      29.785904    30.033510    29.570880    29.799616  3.952067e+05
# min      88.750000    93.830002    79.779999    90.550003  1.205000e+05
# 25%     141.009995   142.860001   139.625004   140.964996  4.273000e+05
# 50%     158.790001   160.759995   156.540001   159.045006  5.644500e+05
# 75%     187.747501   189.462498   185.150002   187.282497  7.415750e+05
# max     247.779999   249.000000   245.899994   247.779999  5.232700e+06
#
#        Dividends  Stock Splits
# count     1258.0        1258.0
# mean         0.0           0.0
# std          0.0           0.0
# min          0.0           0.0
# 25%          0.0           0.0
# 50%          0.0           0.0
# 75%          0.0           0.0
# max          0.0           0.0

# %%
import plotly.graph_objects as go

fig = go.Figure(data=[go.Candlestick(x=df_FFIV.index[-30:],
                                    open=df_FFIV['Open'][-30:],
                                    high=df_FFIV['High'][-30:],
                                    low=df_FFIV['Low'][-30:],
                                    close=df_FFIV['Close'][-30:])])
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True)
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True)
fig.update_layout(title='Ultimos 30 dias FFIV', yaxis_title='FFIV usd')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 5))
df_FFIV['Close'].hist(bins=30)
plt.title('Histograma Close FFIV')
plt.show()

# %%
# Accion TPR
tickerSymbol3 = "TPR"

# Rango de fecha
startDate = '2018-05-15' #  strings
endDate = '2023-05-15' #  strings

# %%
# Crear ticker yfinance accion
tickerData = yf.Ticker(tickerSymbol3)

# Creacion del DataFrame
df_TPR = tickerData.history(start = startDate, end = endDate)

# %%
df_TPR.describe()
# Out:
#               Open         High          Low        Close        Volume  \
# count  1258.000000  1258.000000  1258.000000  1258.000000  1.258000e+03
# mean     31.797047    32.300050    31.254753    31.771077  4.237191e+06
# std       9.217712     9.275280     9.154733     9.218319  2.116842e+06
# min      10.131060    10.663773     9.683961    10.064470  9.199000e+05
# 25%      26.265774    26.690093    25.827081    26.258821  2.890375e+06
# 50%      32.737625    33.288556    32.132502    32.701427  3.752150e+06
# 75%      39.466243    40.101628    38.787748    39.430271  5.000000e+06
# max      46.717028    47.732443    45.794286    46.726540  2.632200e+07
#
#          Dividends  Stock Splits
# count  1258.000000        1258.0
# mean      0.003660           0.0
# std       0.033576           0.0
# min       0.000000           0.0
# 25%       0.000000           0.0
# 50%       0.000000           0.0
# 75%       0.000000           0.0
# max       0.338000           0.0

# %%
import plotly.graph_objects as go

fig = go.Figure(data=[go.Candlestick(x=df_TPR.index[-30:],
                                    open=df_TPR['Open'][-30:],
                                    high=df_TPR['High'][-30:],
                                    low=df_TPR['Low'][-30:],
                                    close=df_TPR['Close'][-30:])])
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True)
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True)
fig.update_layout(title='Ultimos 30 dias TPR', yaxis_title='TPR usd')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 5))
df_TPR['Close'].hist(bins=30)
plt.title('Histograma Close TPR')
plt.show()

# %%
# Accion TGT
tickerSymbol4 = "TGT"

# Rango de fecha
startDate = '2018-05-15' #  strings
endDate = '2023-05-15' #  strings

# %%
# Crear ticker yfinance accion
tickerData = yf.Ticker(tickerSymbol4)

# Creacion del DataFrame
df_TGT = tickerData.history(start = startDate, end = endDate)

# %%
df_TGT.describe()
# Out:
#               Open         High          Low        Close        Volume  \
# count  1258.000000  1258.000000  1258.000000  1258.000000  1.258000e+03
# mean    141.404295   143.046581   139.834922   141.447090  4.519747e+06
# std      56.947626    57.497253    56.396847    56.939651  3.441553e+06
# min      54.990284    56.801856    54.483046    55.370716  1.495200e+06
# 25%      81.566664    82.193662    80.900479    81.610460  2.916600e+06
# 50%     146.121173   147.748113   144.059411   145.881638  3.743200e+06
# 75%     179.971079   182.005297   178.375884   179.913689  5.069850e+06
# max     254.223961   259.119125   253.972628   257.500854  5.093680e+07
#
#          Dividends  Stock Splits
# count  1258.000000        1258.0
# mean      0.012226           0.0
# std       0.098380           0.0
# min       0.000000           0.0
# 25%       0.000000           0.0
# 50%       0.000000           0.0
# 75%       0.000000           0.0
# max       1.080000           0.0

# %%
import plotly.graph_objects as go

fig = go.Figure(data=[go.Candlestick(x=df_TGT.index[-30:],
                                    open=df_TGT['Open'][-30:],
                                    high=df_TGT['High'][-30:],
                                    low=df_TGT['Low'][-30:],
                                    close=df_TGT['Close'][-30:])])
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True)
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True)
fig.update_layout(title='Ultimos 30 dias TGT', yaxis_title='TGT usd')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 5))
df_TGT['Close'].hist(bins=30)
plt.title('Histograma Close TGT')
plt.show()
