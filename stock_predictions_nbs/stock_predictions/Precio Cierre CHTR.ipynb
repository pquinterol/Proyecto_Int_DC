# %%
# Librerias
import sys

# %%
# Accion Wells Fargo
tickerSymbol = "CHTR"

# Rango de fecha
startDate = '2018-05-15' #  strings
endDate = '2023-05-15' #  strings

# %%
# Check if local computer has the library yfinance. If not, install. Then Import it.
# !{sys.executable} -m pip install yfinance # Check if the machine has yfinance, if not, download yfinance
import yfinance as yf # Import library to access Yahoo finance stock data
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: yfinance in /usr/local/lib/python3.10/dist-packages (0.2.18)
# Requirement already satisfied: pandas>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from yfinance) (1.5.3)
# Requirement already satisfied: numpy>=1.16.5 in /usr/local/lib/python3.10/dist-packages (from yfinance) (1.22.4)
# Requirement already satisfied: requests>=2.26 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2.27.1)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.10/dist-packages (from yfinance) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in /usr/local/lib/python3.10/dist-packages (from yfinance) (4.9.2)
# Requirement already satisfied: appdirs>=1.4.4 in /usr/local/lib/python3.10/dist-packages (from yfinance) (1.4.4)
# Requirement already satisfied: pytz>=2022.5 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2022.7.1)
# Requirement already satisfied: frozendict>=2.3.4 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2.3.7)
# Requirement already satisfied: cryptography>=3.3.2 in /usr/local/lib/python3.10/dist-packages (from yfinance) (40.0.2)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /usr/local/lib/python3.10/dist-packages (from yfinance) (4.11.2)
# Requirement already satisfied: html5lib>=1.1 in /usr/local/lib/python3.10/dist-packages (from yfinance) (1.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4>=4.11.1->yfinance) (2.4.1)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography>=3.3.2->yfinance) (1.15.1)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.10/dist-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26->yfinance) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26->yfinance) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26->yfinance) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26->yfinance) (3.4)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography>=3.3.2->yfinance) (2.21)

# %%
# Crear ticker yfinance accion
tickerData = yf.Ticker(tickerSymbol)

# Creacion del DataFrame
df = tickerData.history(start = startDate, end = endDate)


# El dataframe tiene:
#   - Date (YYY-MM-DD) as an index
#   - Open (price the stock started as)
#   - High (highest price stock reached that day)
#   - Low (lowest price stock reached that day)
#   - Close (price the stock ended the day as)
#   - Volume (how many shares were traded that day)
#   - Dividends (any earnings shared to shareholders)
#   - Stock Splits (any stock price changes)

print('-----------------------')
print('Done!')
print(df.head())
# Out:
# -----------------------
# Done!
#                                  Open        High         Low       Close  \
# Date
# 2018-05-15 00:00:00-04:00  272.329987  274.329987  266.859985  270.309998
# 2018-05-16 00:00:00-04:00  270.799988  274.290009  266.739990  272.329987
# 2018-05-17 00:00:00-04:00  271.970001  273.160004  267.829987  268.170013
# 2018-05-18 00:00:00-04:00  267.690002  270.589996  266.730011  270.170013
# 2018-05-21 00:00:00-04:00  270.000000  270.000000  265.239990  266.549988
#
#                             Volume  Dividends  Stock Splits
# Date
# 2018-05-15 00:00:00-04:00  1775000        0.0           0.0
# 2018-05-16 00:00:00-04:00  1861500        0.0           0.0
# 2018-05-17 00:00:00-04:00  1301700        0.0           0.0
# 2018-05-18 00:00:00-04:00  1643000        0.0           0.0
# 2018-05-21 00:00:00-04:00  2065600        0.0           0.0

# %%
# Mas librerias
import pandas as pd 
import numpy as np

# %%
# Change the date column to a pandas date time column 

# Define string format
date_change = '%Y-%m-%d'

# Create a new date column from the index
df['Date'] = df.index

# Perform the date type change
df['Date'] = pd.to_datetime(df['Date'], format = date_change)

# Create a variable that is the date column
Dates = df['Date']

# %% [markdown]
# "Abierto", "Alto", "Bajo", "Cerca", "Volumen" son útiles, pero hay más datos que se pueden derivar de estos datos.
#
# Los indicadores técnicos financieros son útiles para comprender lo que está sucediendo con una acción en particular.
#
# Crearemos algunos de estos con la ayuda de un paquete llamado ta que significa análisis técnico.
#
# Primero, tendremos que instalar y luego importar el paquete.

# %%
# !pip install pandas_ta
import pandas as pd
import pandas_ta as ta
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pandas_ta
#   Downloading pandas_ta-0.3.14b.tar.gz (115 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.1/115.1 kB 10.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from pandas_ta) (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->pandas_ta) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->pandas_ta) (2022.7.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas->pandas_ta) (1.22.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->pandas_ta) (1.16.0)
# Building wheels for collected packages: pandas_ta
#   Building wheel for pandas_ta (setup.py) ... done
#   Created wheel for pandas_ta: filename=pandas_ta-0.3.14b0-py3-none-any.whl size=218908 sha256=f6e892925a87504e70a1d859479ceacdba056ececd35b52ee2aa3e245f6092f7
#   Stored in directory: /root/.cache/pip/wheels/69/00/ac/f7fa862c34b0e2ef320175100c233377b4c558944f12474cf0
# Successfully built pandas_ta
# Installing collected packages: pandas_ta
# Successfully installed pandas_ta-0.3.14b0

# %%
#Generando nuevas variables SMA.Simple Moving Average (SMA) a 10 -50 y 100 dias. Se llaman variables tecnicas
sma10 = df.ta.sma(10)
sma50 = df.ta.sma(50)
sma100 = df.ta.sma(100)
ema10 = df.ta.ema(10)
ema50 = df.ta.ema(50)
ema100 = df.ta.ema(100)
df = pd.concat([df, sma10, sma50, sma100, ema10, ema50, ema100], axis=1)

# %%
#Otras variables nuevas asoviadas a los retornos.
# Calculate Returns and append to the df DataFrame
#df.ta.log_return(cumulative=True, append=True)
#df.ta.percent_return(cumulative=True, append=True)

# Nuevas columnas con variables agregadas  # retornos acumulads , 
df.columns

#del df['Date']
#columns_to_drop = ['Dividends', 'Stock Splits']
#df = df.drop(columns=columns_to_drop)

# Mostrar
df.tail()
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2023-05-08 00:00:00-04:00  353.170013  353.279999  346.309998  350.500000
# 2023-05-09 00:00:00-04:00  348.000000  348.000000  337.720001  339.000000
# 2023-05-10 00:00:00-04:00  341.440002  341.440002  334.649994  339.940002
# 2023-05-11 00:00:00-04:00  338.470001  342.089996  336.829987  341.709991
# 2023-05-12 00:00:00-04:00  341.100006  341.989990  334.190002  338.089996
#
#                             Volume  Dividends  Stock Splits  \
# Date
# 2023-05-08 00:00:00-04:00   731500        0.0           0.0
# 2023-05-09 00:00:00-04:00  1035300        0.0           0.0
# 2023-05-10 00:00:00-04:00   619700        0.0           0.0
# 2023-05-11 00:00:00-04:00   664300        0.0           0.0
# 2023-05-12 00:00:00-04:00   779300        0.0           0.0
#
#                                                Date      SMA_10      SMA_50  \
# Date
# 2023-05-08 00:00:00-04:00 2023-05-08 00:00:00-04:00  348.679004  349.054200
# 2023-05-09 00:00:00-04:00 2023-05-09 00:00:00-04:00  350.185004  348.333201
# 2023-05-10 00:00:00-04:00 2023-05-10 00:00:00-04:00  352.116003  347.779801
# 2023-05-11 00:00:00-04:00 2023-05-11 00:00:00-04:00  352.012003  347.363201
# 2023-05-12 00:00:00-04:00 2023-05-12 00:00:00-04:00  348.951001  346.863201
#
#                             SMA_100      EMA_10      EMA_50     EMA_100
# Date
# 2023-05-08 00:00:00-04:00  361.0808  350.001883  352.594560  361.445434
# 2023-05-09 00:00:00-04:00  360.5440  348.001540  352.061440  361.000970
# 2023-05-10 00:00:00-04:00  360.6600  346.535806  351.586090  360.583921
# 2023-05-11 00:00:00-04:00  360.9428  345.658385  351.198792  360.210180
# 2023-05-12 00:00:00-04:00  361.2741  344.282315  350.684721  359.772156

# %%
df.dropna(inplace=True) #Depurando Nulos

# %%
from fastai.tabular.core import add_datepart

# %%
# Asegurar formato
df['Date'] = pd.to_datetime(df.index.values, format = date_change)

# %%
#!pip install pandas_ta

# %% [markdown]
# Predicciones a 1 día, 5 días y 10 días
#
# Datos de Entrenamiento: 75%

# %% [markdown]
# Modelo BASE: Con todos los datos del S&P 500 y con variables tecnicas adicionales de Pandas _ Ta

# %%
# Parametros del modelo

# Parametrizacion de dias (Shifts)
shifts = [1,5,10,30]

# Entrenamiento: 75%
train_pct = .75

# Parametros del PLOT
w = 16 # width
h = 4 # height

# %%
# Tipos de datos en las columnas

def CorrectColumnTypes(df):
  # Input: dataframe 
  # ouptut: dataframe (with column types changed)

  # Numbers
  for col in df.columns[1:80]:
      df[col] = df[col].astype('float')

  for col in df.columns[-10:]:
      df[col] = df[col].astype('float')

  # Categories 
  for col in df.columns[80:-10]:
      df[col] = df[col].astype('category')


  return df

# %%
del df['Date']
df.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Volume', 'Dividends', 'Stock Splits',
#        'SMA_10', 'SMA_50', 'SMA_100', 'EMA_10', 'EMA_50', 'EMA_100'],
#       dtype='object')

# %%
# Nueva columna al DataFrame "Close_lag" que contiene los valores de la columna "Close" desplazados hacia atrás en shiftdays días. Esto puede ser útil para realizar análisis de series de tiempo, cálculos de diferencias entre valores consecutivos o construir modelos predictivos que utilicen valores pasados como características
# Crear los "lags ""
def CreateLags(df,lag_size):
  # inputs: dataframe , size of the lag (int)
  # ouptut: dataframe ( with extra lag column), shift size (int)

  # add lag
  shiftdays = lag_size
  shift = -shiftdays
  df['Close_lag'] = df['Close'].shift(shift)
  return df, shift

# %% [markdown]
# Finalmente, dividiremos los datos históricos en los conjuntos de prueba y tren.
#
# Dividiremos las x y la y también para esto.
#
# Terminaremos con un conjunto de prueba y entrenamiento para las x y las y.

# %%
# Split the testing and training data 
def SplitData(df, train_pct, shift):
  # inputs: dataframe , training_pct (float between 0 and 1), size of the lag (int)
  # ouptut: x train dataframe, y train data frame, x test dataframe, y test dataframe, train data frame, test dataframe

  train_pt = int(len(df)*train_pct)
  
  train = df.iloc[:train_pt,:]
  test = df.iloc[train_pt:,:]
  
  x_train = train.iloc[:shift,1:-1]
  y_train = train['Close_lag'][:shift]
  x_test = test.iloc[:shift,1:-1]
  y_test = test['Close'][:shift]

  return x_train, y_train, x_test, y_test, train, test

# %%
# !{sys.executable} -m pip install plotly # Download plotly 
import plotly.graph_objs as go  # Import the graph ojbects
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (5.13.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly) (8.2.2)

# %%
# Function para hacer los plots
def PlotModelResults_Plotly(train, test, pred, ticker, w, h, shift_days,name):
  # inputs: train dataframe, test dataframe, predicted value (list), ticker ('string'), width (int), height (int), shift size (int), name (string)
  # output: None

  # Create lines of the training actual, testing actual, prediction 
  D1 = go.Scatter(x=train.index,y=train['Close'],name = 'Train Actual') # Training actuals
  D2 = go.Scatter(x=test.index[:shift],y=test['Close'],name = 'Test Actual') # Testing actuals
  D3 = go.Scatter(x=test.index[:shift],y=pred,name = 'Our Prediction') # Testing predction

  # Combine in an object  
  line = {'data': [D1,D2,D3],
          'layout': {
              'xaxis' :{'title': 'Date'},
              'yaxis' :{'title': '$'},
              'title' : name + ' - ' + tickerSymbol + ' - ' + str(shift_days)
          }}
  # Send object to a figure 
  fig = go.Figure(line)

  # Show figure
  fig.show()

# %% [markdown]
# ```
#
# ```
#
# Modelo de Prediccion

# %%
# Import sklearn librerias seleccionadas para el modelo

# !{sys.executable} -m pip install sklearn # Dsklearn 
from sklearn.metrics import mean_squared_error # error cuadratico medio
from sklearn.linear_model import LinearRegression # Modelo regresion lineal
from sklearn.neural_network import MLPRegressor # IModelo red neuronal artificial 
from sklearn.preprocessing import StandardScaler # Funcion para escalar y desescalar la red neuronal
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting sklearn
#   Downloading sklearn-0.0.post5.tar.gz (3.7 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: sklearn
#   Building wheel for sklearn (setup.py) ... done
#   Created wheel for sklearn: filename=sklearn-0.0.post5-py3-none-any.whl size=2950 sha256=21fb46c8595408004e1a32f9475efd860bc9c13f73ea57b2e5810fb9fedc02cf
#   Stored in directory: /root/.cache/pip/wheels/38/1f/8d/4f812c590e074c1e928f5cec67bf5053b71f38e2648739403a
# Successfully built sklearn
# Installing collected packages: sklearn
# Successfully installed sklearn-0.0.post5

# %% [markdown]
# **Modelo Base: Con todas las variables del indice mas variables tecnicas**

# %%
# Modelo Base regresion lineal 

from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_squared_error

def LinearRegression_fnc(x_train, y_train, x_test, y_test, cv=5):
    # Inputs: x train data, y train data, x test data, y test data (all dataframes)
    #        cv: número de folds en la validación cruzada (por defecto, 5)
    # Output: the predicted values for the test data (list)

    lr = LinearRegression()
    lr.fit(x_train, y_train)

    # Realizar la validación cruzada y obtener el rendimiento del modelo
    scores = cross_val_score(lr, x_train, y_train, cv=cv, scoring='r2')
    lr_R2_cv = scores.mean()
    lr_MSE_cv = -scores.mean()

    lr_pred = lr.predict(x_test)
    lr_MSE = mean_squared_error(y_test, lr_pred)
    lr_R2 = lr.score(x_test, y_test)
    print('Linear Regression R2: {}'.format(lr_R2))
    print('Linear Regression MSE: {}'.format(lr_MSE))
    print('Linear Regression R2 (CV): {}'.format(lr_R2_cv))
    print('Coeficiente: ', lr.coef_)
    print('Intercepto: ', lr.intercept_)

    return lr_pred

# %%
# Funcion para red neuronal

from sklearn.neural_network import MLPRegressor
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error

def ANN_func(x_train, y_train, x_test, y_test):
    # Scaling data
    scaler = StandardScaler()
    scaler.fit(x_train)
    x_train_scaled = scaler.transform(x_train)
    x_test_scaled = scaler.transform(x_test)

    MLP = MLPRegressor(random_state=1, max_iter=1000, hidden_layer_sizes=(100,),
                       activation='identity', learning_rate='adaptive')

    MLP.fit(x_train_scaled, y_train)

    # Perform cross-validation
    MLP_cv_scores = cross_val_score(MLP, x_train_scaled, y_train, cv=5)
    MLP_cv_R2 = MLP_cv_scores.mean()
    MLP_cv_MSE = -MLP_cv_scores.mean()

    MLP_pred = MLP.predict(x_test_scaled)
    MLP_MSE = mean_squared_error(y_test, MLP_pred)
    MLP_R2 = MLP.score(x_test_scaled, y_test)

    print('Multi-layer Perceptron R2 Test: {}'.format(MLP_R2))
    print('Multi-layer Perceptron MSE: {}'.format(MLP_MSE))
    print('Multi-layer Perceptron R2 (CV): {}'.format(MLP_cv_R2))

    return MLP_pred

# %%
## Modelando con cada periodo. Para cada accion, tendremos una predicción para cada duración de tiempo en el futuro

for j in shifts: 
  print(str(j) + ' days out:')
  print('------------')
  df_lag, shift = CreateLags(df,j)
  df_lag = CorrectColumnTypes(df_lag)
  x_train, y_train, x_test, y_test, train, test = SplitData(df, train_pct, shift)

  # Linear Regression
  print("Linear Regression")
  lr_pred = LinearRegression_fnc(x_train,y_train, x_test, y_test)
  PlotModelResults_Plotly(train, test, lr_pred, tickerSymbol, w, h, j, 'Linear Regression')

  # Artificial Neuarl Network 
  print("ANN")
  MLP_pred = ANN_func(x_train,y_train, x_test, y_test)
  PlotModelResults_Plotly(train, test, MLP_pred, tickerSymbol, w, h, j, 'ANN')
  print('------------')
# Out:
# 1 days out:
# ------------
# Linear Regression
# Linear Regression R2: 0.9973710878434618
# Linear Regression MSE: 12.841639982647322
# Linear Regression R2 (CV): 0.9578889164812292
# Coeficiente:  [ 1.54638832e-01  2.37918712e-01  7.48505061e-01 -1.40054690e-07
#  -9.99200722e-16 -9.71445147e-17  2.86364662e-01 -8.90259849e-02
#  -1.80389487e-01 -5.86517838e-01  2.86851954e-01  1.39203026e-01]
# Intercepto:  3.0146324665691964
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="e8b3a78d-82eb-403c-946e-528a63d1fb7e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e8b3a78d-82eb-403c-946e-528a63d1fb7e")) {                    Plotly.newPlot(                        "e8b3a78d-82eb-403c-946e-528a63d1fb7e",                        [{"name":"Train Actual","x":["2018-10-04T00:00:00-04:00","2018-10-05T00:00:00-04:00","2018-10-08T00:00:00-04:00","2018-10-09T00:00:00-04:00","2018-10-10T00:00:00-04:00","2018-10-11T00:00:00-04:00","2018-10-12T00:00:00-04:00","2018-10-15T00:00:00-04:00","2018-10-16T00:00:00-04:00","2018-10-17T00:00:00-04:00","2018-10-18T00:00:00-04:00","2018-10-19T00:00:00-04:00","2018-10-22T00:00:00-04:00","2018-10-23T00:00:00-04:00","2018-10-24T00:00:00-04:00","2018-10-25T00:00:00-04:00","2018-10-26T00:00:00-04:00","2018-10-29T00:00:00-04:00","2018-10-30T00:00:00-04:00","2018-10-31T00:00:00-04:00","2018-11-01T00:00:00-04:00","2018-11-02T00:00:00-04:00","2018-11-05T00:00:00-05:00","2018-11-06T00:00:00-05:00","2018-11-07T00:00:00-05:00","2018-11-08T00:00:00-05:00","2018-11-09T00:00:00-05:00","2018-11-12T00:00:00-05:00","2018-11-13T00:00:00-05:00","2018-11-14T00:00:00-05:00","2018-11-15T00:00:00-05:00","2018-11-16T00:00:00-05:00","2018-11-19T00:00:00-05:00","2018-11-20T00:00:00-05:00","2018-11-21T00:00:00-05:00","2018-11-23T00:00:00-05:00","2018-11-26T00:00:00-05:00","2018-11-27T00:00:00-05:00","2018-11-28T00:00:00-05:00","2018-11-29T00:00:00-05:00","2018-11-30T00:00:00-05:00","2018-12-03T00:00:00-05:00","2018-12-04T00:00:00-05:00","2018-12-06T00:00:00-05:00","2018-12-07T00:00:00-05:00","2018-12-10T00:00:00-05:00","2018-12-11T00:00:00-05:00","2018-12-12T00:00:00-05:00","2018-12-13T00:00:00-05:00","2018-12-14T00:00:00-05:00","2018-12-17T00:00:00-05:00","2018-12-18T00:00:00-05:00","2018-12-19T00:00:00-05:00","2018-12-20T00:00:00-05:00","2018-12-21T00:00:00-05:00","2018-12-24T00:00:00-05:00","2018-12-26T00:00:00-05:00","2018-12-27T00:00:00-05:00","2018-12-28T00:00:00-05:00","2018-12-31T00:00:00-05:00","2019-01-02T00:00:00-05:00","2019-01-03T00:00:00-05:00","2019-01-04T00:00:00-05:00","2019-01-07T00:00:00-05:00","2019-01-08T00:00:00-05:00","2019-01-09T00:00:00-05:00","2019-01-10T00:00:00-05:00","2019-01-11T00:00:00-05:00","2019-01-14T00:00:00-05:00","2019-01-15T00:00:00-05:00","2019-01-16T00:00:00-05:00","2019-01-17T00:00:00-05:00","2019-01-18T00:00:00-05:00","2019-01-22T00:00:00-05:00","2019-01-23T00:00:00-05:00","2019-01-24T00:00:00-05:00","2019-01-25T00:00:00-05:00","2019-01-28T00:00:00-05:00","2019-01-29T00:00:00-05:00","2019-01-30T00:00:00-05:00","2019-01-31T00:00:00-05:00","2019-02-01T00:00:00-05:00","2019-02-04T00:00:00-05:00","2019-02-05T00:00:00-05:00","2019-02-06T00:00:00-05:00","2019-02-07T00:00:00-05:00","2019-02-08T00:00:00-05:00","2019-02-11T00:00:00-05:00","2019-02-12T00:00:00-05:00","2019-02-13T00:00:00-05:00","2019-02-14T00:00:00-05:00","2019-02-15T00:00:00-05:00","2019-02-19T00:00:00-05:00","2019-02-20T00:00:00-05:00","2019-02-21T00:00:00-05:00","2019-02-22T00:00:00-05:00","2019-02-25T00:00:00-05:00","2019-02-26T00:00:00-05:00","2019-02-27T00:00:00-05:00","2019-02-28T00:00:00-05:00","2019-03-01T00:00:00-05:00","2019-03-04T00:00:00-05:00","2019-03-05T00:00:00-05:00","2019-03-06T00:00:00-05:00","2019-03-07T00:00:00-05:00","2019-03-08T00:00:00-05:00","2019-03-11T00:00:00-04:00","2019-03-12T00:00:00-04:00","2019-03-13T00:00:00-04:00","2019-03-14T00:00:00-04:00","2019-03-15T00:00:00-04:00","2019-03-18T00:00:00-04:00","2019-03-19T00:00:00-04:00","2019-03-20T00:00:00-04:00","2019-03-21T00:00:00-04:00","2019-03-22T00:00:00-04:00","2019-03-25T00:00:00-04:00","2019-03-26T00:00:00-04:00","2019-03-27T00:00:00-04:00","2019-03-28T00:00:00-04:00","2019-03-29T00:00:00-04:00","2019-04-01T00:00:00-04:00","2019-04 ...
# ANN
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning:
#
# Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning:
#
# Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning:
#
# Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning:
#
# Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning:
#
# Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
# Multi-layer Perceptron R2 Test: 0.9977145027039296
# Multi-layer Perceptron MSE: 11.164136231960947
# Multi-layer Perceptron R2 (CV): 0.9522984685881222
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning:
#
# Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="c0336919-546b-4249-a252-5a5d18b5b59c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c0336919-546b-4249-a252-5a5d18b5b59c")) {                    Plotly.newPlot(                        "c0336919-546b-4249-a252-5a5d18b5b59c",                        [{"name":"Train Actual","x":["2018-10-04T00:00:00-04:00","2018-10-05T00:00:00-04:00","2018-10-08T00:00:00-04:00","2018-10-09T00:00:00-04:00","2018-10-10T00:00:00-04:00","2018-10-11T00:00:00-04:00","2018-10-12T00:00:00-04:00","2018-10-15T00:00:00-04:00","2018-10-16T00:00:00-04:00","2018-10-17T00:00:00-04:00","2018-10-18T00:00:00-04:00","2018-10-19T00:00:00-04:00","2018-10-22T00:00:00-04:00","2018-10-23T00:00:00-04:00","2018-10-24T00:00:00-04:00","2018-10-25T00:00:00-04:00","2018-10-26T00:00:00-04:00","2018-10-29T00:00:00-04:00","2018-10-30T00:00:00-04:00","2018-10-31T00:00:00-04:00","2018-11-01T00:00:00-04:00","2018-11-02T00:00:00-04:00","2018-11-05T00:00:00-05:00","2018-11-06T00:00:00-05:00","2018-11-07T00:00:00-05:00","2018-11-08T00:00:00-05:00","2018-11-09T00:00:00-05:00","2018-11-12T00:00:00-05:00","2018-11-13T00:00:00-05:00","2018-11-14T00:00:00-05:00","2018-11-15T00:00:00-05:00","2018-11-16T00:00:00-05:00","2018-11-19T00:00:00-05:00","2018-11-20T00:00:00-05:00","2018-11-21T00:00:00-05:00","2018-11-23T00:00:00-05:00","2018-11-26T00:00:00-05:00","2018-11-27T00:00:00-05:00","2018-11-28T00:00:00-05:00","2018-11-29T00:00:00-05:00","2018-11-30T00:00:00-05:00","2018-12-03T00:00:00-05:00","2018-12-04T00:00:00-05:00","2018-12-06T00:00:00-05:00","2018-12-07T00:00:00-05:00","2018-12-10T00:00:00-05:00","2018-12-11T00:00:00-05:00","2018-12-12T00:00:00-05:00","2018-12-13T00:00:00-05:00","2018-12-14T00:00:00-05:00","2018-12-17T00:00:00-05:00","2018-12-18T00:00:00-05:00","2018-12-19T00:00:00-05:00","2018-12-20T00:00:00-05:00","2018-12-21T00:00:00-05:00","2018-12-24T00:00:00-05:00","2018-12-26T00:00:00-05:00","2018-12-27T00:00:00-05:00","2018-12-28T00:00:00-05:00","2018-12-31T00:00:00-05:00","2019-01-02T00:00:00-05:00","2019-01-03T00:00:00-05:00","2019-01-04T00:00:00-05:00","2019-01-07T00:00:00-05:00","2019-01-08T00:00:00-05:00","2019-01-09T00:00:00-05:00","2019-01-10T00:00:00-05:00","2019-01-11T00:00:00-05:00","2019-01-14T00:00:00-05:00","2019-01-15T00:00:00-05:00","2019-01-16T00:00:00-05:00","2019-01-17T00:00:00-05:00","2019-01-18T00:00:00-05:00","2019-01-22T00:00:00-05:00","2019-01-23T00:00:00-05:00","2019-01-24T00:00:00-05:00","2019-01-25T00:00:00-05:00","2019-01-28T00:00:00-05:00","2019-01-29T00:00:00-05:00","2019-01-30T00:00:00-05:00","2019-01-31T00:00:00-05:00","2019-02-01T00:00:00-05:00","2019-02-04T00:00:00-05:00","2019-02-05T00:00:00-05:00","2019-02-06T00:00:00-05:00","2019-02-07T00:00:00-05:00","2019-02-08T00:00:00-05:00","2019-02-11T00:00:00-05:00","2019-02-12T00:00:00-05:00","2019-02-13T00:00:00-05:00","2019-02-14T00:00:00-05:00","2019-02-15T00:00:00-05:00","2019-02-19T00:00:00-05:00","2019-02-20T00:00:00-05:00","2019-02-21T00:00:00-05:00","2019-02-22T00:00:00-05:00","2019-02-25T00:00:00-05:00","2019-02-26T00:00:00-05:00","2019-02-27T00:00:00-05:00","2019-02-28T00:00:00-05:00","2019-03-01T00:00:00-05:00","2019-03-04T00:00:00-05:00","2019-03-05T00:00:00-05:00","2019-03-06T00:00:00-05:00","2019-03-07T00:00:00-05:00","2019-03-08T00:00:00-05:00","2019-03-11T00:00:00-04:00","2019-03-12T00:00:00-04:00","2019-03-13T00:00:00-04:00","2019-03-14T00:00:00-04:00","2019-03-15T00:00:00-04:00","2019-03-18T00:00:00-04:00","2019-03-19T00:00:00-04:00","2019-03-20T00:00:00-04:00","2019-03-21T00:00:00-04:00","2019-03-22T00:00:00-04:00","2019-03-25T00:00:00-04:00","2019-03-26T00:00:00-04:00","2019-03-27T00:00:00-04:00","2019-03-28T00:00:00-04:00","2019-03-29T00:00:00-04:00","2019-04-01T00:00:00-04:00","2019-04 ...
# ------------
# 5 days out:
# ------------
# Linear Regression
# Linear Regression R2: 0.9342765668554152
# Linear Regression MSE: 321.4115004455518
# Linear Regression R2 (CV): 0.7952786494358273
# Coeficiente:  [ 3.79411955e-01  2.51564491e-02  8.28065941e-01 -4.20924255e-06
#  -5.82867088e-16 -9.02056208e-16  7.14134648e-01 -2.63529359e-01
#  -7.78662234e-01 -1.43178630e+00  7.30753791e-01  7.76732747e-01]
# Intercepto:  18.95538208955952
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="b2dfcb29-958e-4e58-83e7-9b92c8642f62" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b2dfcb29-958e-4e58-83e7-9b92c8642f62")) {                    Plotly.newPlot(                        "b2dfcb29-958e-4e58-83e7-9b92c8642f62",                        [{"name":"Train Actual","x":["2018-10-04T00:00:00-04:00","2018-10-05T00:00:00-04:00","2018-10-08T00:00:00-04:00","2018-10-09T00:00:00-04:00","2018-10-10T00:00:00-04:00","2018-10-11T00:00:00-04:00","2018-10-12T00:00:00-04:00","2018-10-15T00:00:00-04:00","2018-10-16T00:00:00-04:00","2018-10-17T00:00:00-04:00","2018-10-18T00:00:00-04:00","2018-10-19T00:00:00-04:00","2018-10-22T00:00:00-04:00","2018-10-23T00:00:00-04:00","2018-10-24T00:00:00-04:00","2018-10-25T00:00:00-04:00","2018-10-26T00:00:00-04:00","2018-10-29T00:00:00-04:00","2018-10-30T00:00:00-04:00","2018-10-31T00:00:00-04:00","2018-11-01T00:00:00-04:00","2018-11-02T00:00:00-04:00","2018-11-05T00:00:00-05:00","2018-11-06T00:00:00-05:00","2018-11-07T00:00:00-05:00","2018-11-08T00:00:00-05:00","2018-11-09T00:00:00-05:00","2018-11-12T00:00:00-05:00","2018-11-13T00:00:00-05:00","2018-11-14T00:00:00-05:00","2018-11-15T00:00:00-05:00","2018-11-16T00:00:00-05:00","2018-11-19T00:00:00-05:00","2018-11-20T00:00:00-05:00","2018-11-21T00:00:00-05:00","2018-11-23T00:00:00-05:00","2018-11-26T00:00:00-05:00","2018-11-27T00:00:00-05:00","2018-11-28T00:00:00-05:00","2018-11-29T00:00:00-05:00","2018-11-30T00:00:00-05:00","2018-12-03T00:00:00-05:00","2018-12-04T00:00:00-05:00","2018-12-06T00:00:00-05:00","2018-12-07T00:00:00-05:00","2018-12-10T00:00:00-05:00","2018-12-11T00:00:00-05:00","2018-12-12T00:00:00-05:00","2018-12-13T00:00:00-05:00","2018-12-14T00:00:00-05:00","2018-12-17T00:00:00-05:00","2018-12-18T00:00:00-05:00","2018-12-19T00:00:00-05:00","2018-12-20T00:00:00-05:00","2018-12-21T00:00:00-05:00","2018-12-24T00:00:00-05:00","2018-12-26T00:00:00-05:00","2018-12-27T00:00:00-05:00","2018-12-28T00:00:00-05:00","2018-12-31T00:00:00-05:00","2019-01-02T00:00:00-05:00","2019-01-03T00:00:00-05:00","2019-01-04T00:00:00-05:00","2019-01-07T00:00:00-05:00","2019-01-08T00:00:00-05:00","2019-01-09T00:00:00-05:00","2019-01-10T00:00:00-05:00","2019-01-11T00:00:00-05:00","2019-01-14T00:00:00-05:00","2019-01-15T00:00:00-05:00","2019-01-16T00:00:00-05:00","2019-01-17T00:00:00-05:00","2019-01-18T00:00:00-05:00","2019-01-22T00:00:00-05:00","2019-01-23T00:00:00-05:00","2019-01-24T00:00:00-05:00","2019-01-25T00:00:00-05:00","2019-01-28T00:00:00-05:00","2019-01-29T00:00:00-05:00","2019-01-30T00:00:00-05:00","2019-01-31T00:00:00-05:00","2019-02-01T00:00:00-05:00","2019-02-04T00:00:00-05:00","2019-02-05T00:00:00-05:00","2019-02-06T00:00:00-05:00","2019-02-07T00:00:00-05:00","2019-02-08T00:00:00-05:00","2019-02-11T00:00:00-05:00","2019-02-12T00:00:00-05:00","2019-02-13T00:00:00-05:00","2019-02-14T00:00:00-05:00","2019-02-15T00:00:00-05:00","2019-02-19T00:00:00-05:00","2019-02-20T00:00:00-05:00","2019-02-21T00:00:00-05:00","2019-02-22T00:00:00-05:00","2019-02-25T00:00:00-05:00","2019-02-26T00:00:00-05:00","2019-02-27T00:00:00-05:00","2019-02-28T00:00:00-05:00","2019-03-01T00:00:00-05:00","2019-03-04T00:00:00-05:00","2019-03-05T00:00:00-05:00","2019-03-06T00:00:00-05:00","2019-03-07T00:00:00-05:00","2019-03-08T00:00:00-05:00","2019-03-11T00:00:00-04:00","2019-03-12T00:00:00-04:00","2019-03-13T00:00:00-04:00","2019-03-14T00:00:00-04:00","2019-03-15T00:00:00-04:00","2019-03-18T00:00:00-04:00","2019-03-19T00:00:00-04:00","2019-03-20T00:00:00-04:00","2019-03-21T00:00:00-04:00","2019-03-22T00:00:00-04:00","2019-03-25T00:00:00-04:00","2019-03-26T00:00:00-04:00","2019-03-27T00:00:00-04:00","2019-03-28T00:00:00-04:00","2019-03-29T00:00:00-04:00","2019-04-01T00:00:00-04:00","2019-04 ...
# ANN
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning:
#
# Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
# Multi-layer Perceptron R2 Test: 0.9901963104713891
# Multi-layer Perceptron MSE: 47.94360870286919
# Multi-layer Perceptron R2 (CV): 0.8169825573394295
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning:
#
# Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="9f45982e-130d-4046-b843-1ffd43b1bdc9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9f45982e-130d-4046-b843-1ffd43b1bdc9")) {                    Plotly.newPlot(                        "9f45982e-130d-4046-b843-1ffd43b1bdc9",                        [{"name":"Train Actual","x":["2018-10-04T00:00:00-04:00","2018-10-05T00:00:00-04:00","2018-10-08T00:00:00-04:00","2018-10-09T00:00:00-04:00","2018-10-10T00:00:00-04:00","2018-10-11T00:00:00-04:00","2018-10-12T00:00:00-04:00","2018-10-15T00:00:00-04:00","2018-10-16T00:00:00-04:00","2018-10-17T00:00:00-04:00","2018-10-18T00:00:00-04:00","2018-10-19T00:00:00-04:00","2018-10-22T00:00:00-04:00","2018-10-23T00:00:00-04:00","2018-10-24T00:00:00-04:00","2018-10-25T00:00:00-04:00","2018-10-26T00:00:00-04:00","2018-10-29T00:00:00-04:00","2018-10-30T00:00:00-04:00","2018-10-31T00:00:00-04:00","2018-11-01T00:00:00-04:00","2018-11-02T00:00:00-04:00","2018-11-05T00:00:00-05:00","2018-11-06T00:00:00-05:00","2018-11-07T00:00:00-05:00","2018-11-08T00:00:00-05:00","2018-11-09T00:00:00-05:00","2018-11-12T00:00:00-05:00","2018-11-13T00:00:00-05:00","2018-11-14T00:00:00-05:00","2018-11-15T00:00:00-05:00","2018-11-16T00:00:00-05:00","2018-11-19T00:00:00-05:00","2018-11-20T00:00:00-05:00","2018-11-21T00:00:00-05:00","2018-11-23T00:00:00-05:00","2018-11-26T00:00:00-05:00","2018-11-27T00:00:00-05:00","2018-11-28T00:00:00-05:00","2018-11-29T00:00:00-05:00","2018-11-30T00:00:00-05:00","2018-12-03T00:00:00-05:00","2018-12-04T00:00:00-05:00","2018-12-06T00:00:00-05:00","2018-12-07T00:00:00-05:00","2018-12-10T00:00:00-05:00","2018-12-11T00:00:00-05:00","2018-12-12T00:00:00-05:00","2018-12-13T00:00:00-05:00","2018-12-14T00:00:00-05:00","2018-12-17T00:00:00-05:00","2018-12-18T00:00:00-05:00","2018-12-19T00:00:00-05:00","2018-12-20T00:00:00-05:00","2018-12-21T00:00:00-05:00","2018-12-24T00:00:00-05:00","2018-12-26T00:00:00-05:00","2018-12-27T00:00:00-05:00","2018-12-28T00:00:00-05:00","2018-12-31T00:00:00-05:00","2019-01-02T00:00:00-05:00","2019-01-03T00:00:00-05:00","2019-01-04T00:00:00-05:00","2019-01-07T00:00:00-05:00","2019-01-08T00:00:00-05:00","2019-01-09T00:00:00-05:00","2019-01-10T00:00:00-05:00","2019-01-11T00:00:00-05:00","2019-01-14T00:00:00-05:00","2019-01-15T00:00:00-05:00","2019-01-16T00:00:00-05:00","2019-01-17T00:00:00-05:00","2019-01-18T00:00:00-05:00","2019-01-22T00:00:00-05:00","2019-01-23T00:00:00-05:00","2019-01-24T00:00:00-05:00","2019-01-25T00:00:00-05:00","2019-01-28T00:00:00-05:00","2019-01-29T00:00:00-05:00","2019-01-30T00:00:00-05:00","2019-01-31T00:00:00-05:00","2019-02-01T00:00:00-05:00","2019-02-04T00:00:00-05:00","2019-02-05T00:00:00-05:00","2019-02-06T00:00:00-05:00","2019-02-07T00:00:00-05:00","2019-02-08T00:00:00-05:00","2019-02-11T00:00:00-05:00","2019-02-12T00:00:00-05:00","2019-02-13T00:00:00-05:00","2019-02-14T00:00:00-05:00","2019-02-15T00:00:00-05:00","2019-02-19T00:00:00-05:00","2019-02-20T00:00:00-05:00","2019-02-21T00:00:00-05:00","2019-02-22T00:00:00-05:00","2019-02-25T00:00:00-05:00","2019-02-26T00:00:00-05:00","2019-02-27T00:00:00-05:00","2019-02-28T00:00:00-05:00","2019-03-01T00:00:00-05:00","2019-03-04T00:00:00-05:00","2019-03-05T00:00:00-05:00","2019-03-06T00:00:00-05:00","2019-03-07T00:00:00-05:00","2019-03-08T00:00:00-05:00","2019-03-11T00:00:00-04:00","2019-03-12T00:00:00-04:00","2019-03-13T00:00:00-04:00","2019-03-14T00:00:00-04:00","2019-03-15T00:00:00-04:00","2019-03-18T00:00:00-04:00","2019-03-19T00:00:00-04:00","2019-03-20T00:00:00-04:00","2019-03-21T00:00:00-04:00","2019-03-22T00:00:00-04:00","2019-03-25T00:00:00-04:00","2019-03-26T00:00:00-04:00","2019-03-27T00:00:00-04:00","2019-03-28T00:00:00-04:00","2019-03-29T00:00:00-04:00","2019-04-01T00:00:00-04:00","2019-04 ...
# ------------
# 10 days out:
# ------------
# Linear Regression
# Linear Regression R2: 0.7347362707802121
# Linear Regression MSE: 1306.1466033606182
# Linear Regression R2 (CV): 0.5551891696902634
# Coeficiente:  [ 7.45368895e-01 -4.28787421e-01  7.55634117e-01 -7.51238892e-06
#   3.34801631e-15  3.05311332e-16  1.15500708e-01 -3.91678907e-01
#  -1.44340128e+00 -8.31723341e-01  8.15399476e-01  1.62243408e+00]
# Intercepto:  35.116873630819555
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="bd8a6b3f-8c5f-4b1e-b42f-ee92e139242e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bd8a6b3f-8c5f-4b1e-b42f-ee92e139242e")) {                    Plotly.newPlot(                        "bd8a6b3f-8c5f-4b1e-b42f-ee92e139242e",                        [{"name":"Train Actual","x":["2018-10-04T00:00:00-04:00","2018-10-05T00:00:00-04:00","2018-10-08T00:00:00-04:00","2018-10-09T00:00:00-04:00","2018-10-10T00:00:00-04:00","2018-10-11T00:00:00-04:00","2018-10-12T00:00:00-04:00","2018-10-15T00:00:00-04:00","2018-10-16T00:00:00-04:00","2018-10-17T00:00:00-04:00","2018-10-18T00:00:00-04:00","2018-10-19T00:00:00-04:00","2018-10-22T00:00:00-04:00","2018-10-23T00:00:00-04:00","2018-10-24T00:00:00-04:00","2018-10-25T00:00:00-04:00","2018-10-26T00:00:00-04:00","2018-10-29T00:00:00-04:00","2018-10-30T00:00:00-04:00","2018-10-31T00:00:00-04:00","2018-11-01T00:00:00-04:00","2018-11-02T00:00:00-04:00","2018-11-05T00:00:00-05:00","2018-11-06T00:00:00-05:00","2018-11-07T00:00:00-05:00","2018-11-08T00:00:00-05:00","2018-11-09T00:00:00-05:00","2018-11-12T00:00:00-05:00","2018-11-13T00:00:00-05:00","2018-11-14T00:00:00-05:00","2018-11-15T00:00:00-05:00","2018-11-16T00:00:00-05:00","2018-11-19T00:00:00-05:00","2018-11-20T00:00:00-05:00","2018-11-21T00:00:00-05:00","2018-11-23T00:00:00-05:00","2018-11-26T00:00:00-05:00","2018-11-27T00:00:00-05:00","2018-11-28T00:00:00-05:00","2018-11-29T00:00:00-05:00","2018-11-30T00:00:00-05:00","2018-12-03T00:00:00-05:00","2018-12-04T00:00:00-05:00","2018-12-06T00:00:00-05:00","2018-12-07T00:00:00-05:00","2018-12-10T00:00:00-05:00","2018-12-11T00:00:00-05:00","2018-12-12T00:00:00-05:00","2018-12-13T00:00:00-05:00","2018-12-14T00:00:00-05:00","2018-12-17T00:00:00-05:00","2018-12-18T00:00:00-05:00","2018-12-19T00:00:00-05:00","2018-12-20T00:00:00-05:00","2018-12-21T00:00:00-05:00","2018-12-24T00:00:00-05:00","2018-12-26T00:00:00-05:00","2018-12-27T00:00:00-05:00","2018-12-28T00:00:00-05:00","2018-12-31T00:00:00-05:00","2019-01-02T00:00:00-05:00","2019-01-03T00:00:00-05:00","2019-01-04T00:00:00-05:00","2019-01-07T00:00:00-05:00","2019-01-08T00:00:00-05:00","2019-01-09T00:00:00-05:00","2019-01-10T00:00:00-05:00","2019-01-11T00:00:00-05:00","2019-01-14T00:00:00-05:00","2019-01-15T00:00:00-05:00","2019-01-16T00:00:00-05:00","2019-01-17T00:00:00-05:00","2019-01-18T00:00:00-05:00","2019-01-22T00:00:00-05:00","2019-01-23T00:00:00-05:00","2019-01-24T00:00:00-05:00","2019-01-25T00:00:00-05:00","2019-01-28T00:00:00-05:00","2019-01-29T00:00:00-05:00","2019-01-30T00:00:00-05:00","2019-01-31T00:00:00-05:00","2019-02-01T00:00:00-05:00","2019-02-04T00:00:00-05:00","2019-02-05T00:00:00-05:00","2019-02-06T00:00:00-05:00","2019-02-07T00:00:00-05:00","2019-02-08T00:00:00-05:00","2019-02-11T00:00:00-05:00","2019-02-12T00:00:00-05:00","2019-02-13T00:00:00-05:00","2019-02-14T00:00:00-05:00","2019-02-15T00:00:00-05:00","2019-02-19T00:00:00-05:00","2019-02-20T00:00:00-05:00","2019-02-21T00:00:00-05:00","2019-02-22T00:00:00-05:00","2019-02-25T00:00:00-05:00","2019-02-26T00:00:00-05:00","2019-02-27T00:00:00-05:00","2019-02-28T00:00:00-05:00","2019-03-01T00:00:00-05:00","2019-03-04T00:00:00-05:00","2019-03-05T00:00:00-05:00","2019-03-06T00:00:00-05:00","2019-03-07T00:00:00-05:00","2019-03-08T00:00:00-05:00","2019-03-11T00:00:00-04:00","2019-03-12T00:00:00-04:00","2019-03-13T00:00:00-04:00","2019-03-14T00:00:00-04:00","2019-03-15T00:00:00-04:00","2019-03-18T00:00:00-04:00","2019-03-19T00:00:00-04:00","2019-03-20T00:00:00-04:00","2019-03-21T00:00:00-04:00","2019-03-22T00:00:00-04:00","2019-03-25T00:00:00-04:00","2019-03-26T00:00:00-04:00","2019-03-27T00:00:00-04:00","2019-03-28T00:00:00-04:00","2019-03-29T00:00:00-04:00","2019-04-01T00:00:00-04:00","2019-04 ...
# ANN
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning:
#
# Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
# Multi-layer Perceptron R2 Test: 0.9794903630267442
# Multi-layer Perceptron MSE: 100.98852469415964
# Multi-layer Perceptron R2 (CV): 0.6262926012731347
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning:
#
# Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="2069d933-7c00-482a-9c38-3f6679cdd7ad" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2069d933-7c00-482a-9c38-3f6679cdd7ad")) {                    Plotly.newPlot(                        "2069d933-7c00-482a-9c38-3f6679cdd7ad",                        [{"name":"Train Actual","x":["2018-10-04T00:00:00-04:00","2018-10-05T00:00:00-04:00","2018-10-08T00:00:00-04:00","2018-10-09T00:00:00-04:00","2018-10-10T00:00:00-04:00","2018-10-11T00:00:00-04:00","2018-10-12T00:00:00-04:00","2018-10-15T00:00:00-04:00","2018-10-16T00:00:00-04:00","2018-10-17T00:00:00-04:00","2018-10-18T00:00:00-04:00","2018-10-19T00:00:00-04:00","2018-10-22T00:00:00-04:00","2018-10-23T00:00:00-04:00","2018-10-24T00:00:00-04:00","2018-10-25T00:00:00-04:00","2018-10-26T00:00:00-04:00","2018-10-29T00:00:00-04:00","2018-10-30T00:00:00-04:00","2018-10-31T00:00:00-04:00","2018-11-01T00:00:00-04:00","2018-11-02T00:00:00-04:00","2018-11-05T00:00:00-05:00","2018-11-06T00:00:00-05:00","2018-11-07T00:00:00-05:00","2018-11-08T00:00:00-05:00","2018-11-09T00:00:00-05:00","2018-11-12T00:00:00-05:00","2018-11-13T00:00:00-05:00","2018-11-14T00:00:00-05:00","2018-11-15T00:00:00-05:00","2018-11-16T00:00:00-05:00","2018-11-19T00:00:00-05:00","2018-11-20T00:00:00-05:00","2018-11-21T00:00:00-05:00","2018-11-23T00:00:00-05:00","2018-11-26T00:00:00-05:00","2018-11-27T00:00:00-05:00","2018-11-28T00:00:00-05:00","2018-11-29T00:00:00-05:00","2018-11-30T00:00:00-05:00","2018-12-03T00:00:00-05:00","2018-12-04T00:00:00-05:00","2018-12-06T00:00:00-05:00","2018-12-07T00:00:00-05:00","2018-12-10T00:00:00-05:00","2018-12-11T00:00:00-05:00","2018-12-12T00:00:00-05:00","2018-12-13T00:00:00-05:00","2018-12-14T00:00:00-05:00","2018-12-17T00:00:00-05:00","2018-12-18T00:00:00-05:00","2018-12-19T00:00:00-05:00","2018-12-20T00:00:00-05:00","2018-12-21T00:00:00-05:00","2018-12-24T00:00:00-05:00","2018-12-26T00:00:00-05:00","2018-12-27T00:00:00-05:00","2018-12-28T00:00:00-05:00","2018-12-31T00:00:00-05:00","2019-01-02T00:00:00-05:00","2019-01-03T00:00:00-05:00","2019-01-04T00:00:00-05:00","2019-01-07T00:00:00-05:00","2019-01-08T00:00:00-05:00","2019-01-09T00:00:00-05:00","2019-01-10T00:00:00-05:00","2019-01-11T00:00:00-05:00","2019-01-14T00:00:00-05:00","2019-01-15T00:00:00-05:00","2019-01-16T00:00:00-05:00","2019-01-17T00:00:00-05:00","2019-01-18T00:00:00-05:00","2019-01-22T00:00:00-05:00","2019-01-23T00:00:00-05:00","2019-01-24T00:00:00-05:00","2019-01-25T00:00:00-05:00","2019-01-28T00:00:00-05:00","2019-01-29T00:00:00-05:00","2019-01-30T00:00:00-05:00","2019-01-31T00:00:00-05:00","2019-02-01T00:00:00-05:00","2019-02-04T00:00:00-05:00","2019-02-05T00:00:00-05:00","2019-02-06T00:00:00-05:00","2019-02-07T00:00:00-05:00","2019-02-08T00:00:00-05:00","2019-02-11T00:00:00-05:00","2019-02-12T00:00:00-05:00","2019-02-13T00:00:00-05:00","2019-02-14T00:00:00-05:00","2019-02-15T00:00:00-05:00","2019-02-19T00:00:00-05:00","2019-02-20T00:00:00-05:00","2019-02-21T00:00:00-05:00","2019-02-22T00:00:00-05:00","2019-02-25T00:00:00-05:00","2019-02-26T00:00:00-05:00","2019-02-27T00:00:00-05:00","2019-02-28T00:00:00-05:00","2019-03-01T00:00:00-05:00","2019-03-04T00:00:00-05:00","2019-03-05T00:00:00-05:00","2019-03-06T00:00:00-05:00","2019-03-07T00:00:00-05:00","2019-03-08T00:00:00-05:00","2019-03-11T00:00:00-04:00","2019-03-12T00:00:00-04:00","2019-03-13T00:00:00-04:00","2019-03-14T00:00:00-04:00","2019-03-15T00:00:00-04:00","2019-03-18T00:00:00-04:00","2019-03-19T00:00:00-04:00","2019-03-20T00:00:00-04:00","2019-03-21T00:00:00-04:00","2019-03-22T00:00:00-04:00","2019-03-25T00:00:00-04:00","2019-03-26T00:00:00-04:00","2019-03-27T00:00:00-04:00","2019-03-28T00:00:00-04:00","2019-03-29T00:00:00-04:00","2019-04-01T00:00:00-04:00","2019-04 ...
# ------------
# 30 days out:
# ------------
# Linear Regression
# Linear Regression R2: -2.9718412771694465
# Linear Regression MSE: 19582.460921917693
# Linear Regression R2 (CV): -0.3088900834085836
# Coeficiente:  [ 1.34682414e+00 -9.74755722e-01  2.23951411e-01 -1.10874759e-07
#  -1.44328993e-15 -5.55111512e-16  8.22261667e-02  5.90118374e-01
#  -4.02234346e+00  3.47073500e-01 -3.37436330e+00  6.71386715e+00]
# Intercepto:  68.71001798332588
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="bc068f11-fd5a-4ead-8393-1244100d42f1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bc068f11-fd5a-4ead-8393-1244100d42f1")) {                    Plotly.newPlot(                        "bc068f11-fd5a-4ead-8393-1244100d42f1",                        [{"name":"Train Actual","x":["2018-10-04T00:00:00-04:00","2018-10-05T00:00:00-04:00","2018-10-08T00:00:00-04:00","2018-10-09T00:00:00-04:00","2018-10-10T00:00:00-04:00","2018-10-11T00:00:00-04:00","2018-10-12T00:00:00-04:00","2018-10-15T00:00:00-04:00","2018-10-16T00:00:00-04:00","2018-10-17T00:00:00-04:00","2018-10-18T00:00:00-04:00","2018-10-19T00:00:00-04:00","2018-10-22T00:00:00-04:00","2018-10-23T00:00:00-04:00","2018-10-24T00:00:00-04:00","2018-10-25T00:00:00-04:00","2018-10-26T00:00:00-04:00","2018-10-29T00:00:00-04:00","2018-10-30T00:00:00-04:00","2018-10-31T00:00:00-04:00","2018-11-01T00:00:00-04:00","2018-11-02T00:00:00-04:00","2018-11-05T00:00:00-05:00","2018-11-06T00:00:00-05:00","2018-11-07T00:00:00-05:00","2018-11-08T00:00:00-05:00","2018-11-09T00:00:00-05:00","2018-11-12T00:00:00-05:00","2018-11-13T00:00:00-05:00","2018-11-14T00:00:00-05:00","2018-11-15T00:00:00-05:00","2018-11-16T00:00:00-05:00","2018-11-19T00:00:00-05:00","2018-11-20T00:00:00-05:00","2018-11-21T00:00:00-05:00","2018-11-23T00:00:00-05:00","2018-11-26T00:00:00-05:00","2018-11-27T00:00:00-05:00","2018-11-28T00:00:00-05:00","2018-11-29T00:00:00-05:00","2018-11-30T00:00:00-05:00","2018-12-03T00:00:00-05:00","2018-12-04T00:00:00-05:00","2018-12-06T00:00:00-05:00","2018-12-07T00:00:00-05:00","2018-12-10T00:00:00-05:00","2018-12-11T00:00:00-05:00","2018-12-12T00:00:00-05:00","2018-12-13T00:00:00-05:00","2018-12-14T00:00:00-05:00","2018-12-17T00:00:00-05:00","2018-12-18T00:00:00-05:00","2018-12-19T00:00:00-05:00","2018-12-20T00:00:00-05:00","2018-12-21T00:00:00-05:00","2018-12-24T00:00:00-05:00","2018-12-26T00:00:00-05:00","2018-12-27T00:00:00-05:00","2018-12-28T00:00:00-05:00","2018-12-31T00:00:00-05:00","2019-01-02T00:00:00-05:00","2019-01-03T00:00:00-05:00","2019-01-04T00:00:00-05:00","2019-01-07T00:00:00-05:00","2019-01-08T00:00:00-05:00","2019-01-09T00:00:00-05:00","2019-01-10T00:00:00-05:00","2019-01-11T00:00:00-05:00","2019-01-14T00:00:00-05:00","2019-01-15T00:00:00-05:00","2019-01-16T00:00:00-05:00","2019-01-17T00:00:00-05:00","2019-01-18T00:00:00-05:00","2019-01-22T00:00:00-05:00","2019-01-23T00:00:00-05:00","2019-01-24T00:00:00-05:00","2019-01-25T00:00:00-05:00","2019-01-28T00:00:00-05:00","2019-01-29T00:00:00-05:00","2019-01-30T00:00:00-05:00","2019-01-31T00:00:00-05:00","2019-02-01T00:00:00-05:00","2019-02-04T00:00:00-05:00","2019-02-05T00:00:00-05:00","2019-02-06T00:00:00-05:00","2019-02-07T00:00:00-05:00","2019-02-08T00:00:00-05:00","2019-02-11T00:00:00-05:00","2019-02-12T00:00:00-05:00","2019-02-13T00:00:00-05:00","2019-02-14T00:00:00-05:00","2019-02-15T00:00:00-05:00","2019-02-19T00:00:00-05:00","2019-02-20T00:00:00-05:00","2019-02-21T00:00:00-05:00","2019-02-22T00:00:00-05:00","2019-02-25T00:00:00-05:00","2019-02-26T00:00:00-05:00","2019-02-27T00:00:00-05:00","2019-02-28T00:00:00-05:00","2019-03-01T00:00:00-05:00","2019-03-04T00:00:00-05:00","2019-03-05T00:00:00-05:00","2019-03-06T00:00:00-05:00","2019-03-07T00:00:00-05:00","2019-03-08T00:00:00-05:00","2019-03-11T00:00:00-04:00","2019-03-12T00:00:00-04:00","2019-03-13T00:00:00-04:00","2019-03-14T00:00:00-04:00","2019-03-15T00:00:00-04:00","2019-03-18T00:00:00-04:00","2019-03-19T00:00:00-04:00","2019-03-20T00:00:00-04:00","2019-03-21T00:00:00-04:00","2019-03-22T00:00:00-04:00","2019-03-25T00:00:00-04:00","2019-03-26T00:00:00-04:00","2019-03-27T00:00:00-04:00","2019-03-28T00:00:00-04:00","2019-03-29T00:00:00-04:00","2019-04-01T00:00:00-04:00","2019-04 ...
# ANN
# Multi-layer Perceptron R2 Test: 0.9227343467152924
# Multi-layer Perceptron MSE: 380.94463762975715
# Multi-layer Perceptron R2 (CV): -0.03393491568414149
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning:
#
# Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="28009231-4d56-4d0d-8cf8-7caf3ad03b42" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("28009231-4d56-4d0d-8cf8-7caf3ad03b42")) {                    Plotly.newPlot(                        "28009231-4d56-4d0d-8cf8-7caf3ad03b42",                        [{"name":"Train Actual","x":["2018-10-04T00:00:00-04:00","2018-10-05T00:00:00-04:00","2018-10-08T00:00:00-04:00","2018-10-09T00:00:00-04:00","2018-10-10T00:00:00-04:00","2018-10-11T00:00:00-04:00","2018-10-12T00:00:00-04:00","2018-10-15T00:00:00-04:00","2018-10-16T00:00:00-04:00","2018-10-17T00:00:00-04:00","2018-10-18T00:00:00-04:00","2018-10-19T00:00:00-04:00","2018-10-22T00:00:00-04:00","2018-10-23T00:00:00-04:00","2018-10-24T00:00:00-04:00","2018-10-25T00:00:00-04:00","2018-10-26T00:00:00-04:00","2018-10-29T00:00:00-04:00","2018-10-30T00:00:00-04:00","2018-10-31T00:00:00-04:00","2018-11-01T00:00:00-04:00","2018-11-02T00:00:00-04:00","2018-11-05T00:00:00-05:00","2018-11-06T00:00:00-05:00","2018-11-07T00:00:00-05:00","2018-11-08T00:00:00-05:00","2018-11-09T00:00:00-05:00","2018-11-12T00:00:00-05:00","2018-11-13T00:00:00-05:00","2018-11-14T00:00:00-05:00","2018-11-15T00:00:00-05:00","2018-11-16T00:00:00-05:00","2018-11-19T00:00:00-05:00","2018-11-20T00:00:00-05:00","2018-11-21T00:00:00-05:00","2018-11-23T00:00:00-05:00","2018-11-26T00:00:00-05:00","2018-11-27T00:00:00-05:00","2018-11-28T00:00:00-05:00","2018-11-29T00:00:00-05:00","2018-11-30T00:00:00-05:00","2018-12-03T00:00:00-05:00","2018-12-04T00:00:00-05:00","2018-12-06T00:00:00-05:00","2018-12-07T00:00:00-05:00","2018-12-10T00:00:00-05:00","2018-12-11T00:00:00-05:00","2018-12-12T00:00:00-05:00","2018-12-13T00:00:00-05:00","2018-12-14T00:00:00-05:00","2018-12-17T00:00:00-05:00","2018-12-18T00:00:00-05:00","2018-12-19T00:00:00-05:00","2018-12-20T00:00:00-05:00","2018-12-21T00:00:00-05:00","2018-12-24T00:00:00-05:00","2018-12-26T00:00:00-05:00","2018-12-27T00:00:00-05:00","2018-12-28T00:00:00-05:00","2018-12-31T00:00:00-05:00","2019-01-02T00:00:00-05:00","2019-01-03T00:00:00-05:00","2019-01-04T00:00:00-05:00","2019-01-07T00:00:00-05:00","2019-01-08T00:00:00-05:00","2019-01-09T00:00:00-05:00","2019-01-10T00:00:00-05:00","2019-01-11T00:00:00-05:00","2019-01-14T00:00:00-05:00","2019-01-15T00:00:00-05:00","2019-01-16T00:00:00-05:00","2019-01-17T00:00:00-05:00","2019-01-18T00:00:00-05:00","2019-01-22T00:00:00-05:00","2019-01-23T00:00:00-05:00","2019-01-24T00:00:00-05:00","2019-01-25T00:00:00-05:00","2019-01-28T00:00:00-05:00","2019-01-29T00:00:00-05:00","2019-01-30T00:00:00-05:00","2019-01-31T00:00:00-05:00","2019-02-01T00:00:00-05:00","2019-02-04T00:00:00-05:00","2019-02-05T00:00:00-05:00","2019-02-06T00:00:00-05:00","2019-02-07T00:00:00-05:00","2019-02-08T00:00:00-05:00","2019-02-11T00:00:00-05:00","2019-02-12T00:00:00-05:00","2019-02-13T00:00:00-05:00","2019-02-14T00:00:00-05:00","2019-02-15T00:00:00-05:00","2019-02-19T00:00:00-05:00","2019-02-20T00:00:00-05:00","2019-02-21T00:00:00-05:00","2019-02-22T00:00:00-05:00","2019-02-25T00:00:00-05:00","2019-02-26T00:00:00-05:00","2019-02-27T00:00:00-05:00","2019-02-28T00:00:00-05:00","2019-03-01T00:00:00-05:00","2019-03-04T00:00:00-05:00","2019-03-05T00:00:00-05:00","2019-03-06T00:00:00-05:00","2019-03-07T00:00:00-05:00","2019-03-08T00:00:00-05:00","2019-03-11T00:00:00-04:00","2019-03-12T00:00:00-04:00","2019-03-13T00:00:00-04:00","2019-03-14T00:00:00-04:00","2019-03-15T00:00:00-04:00","2019-03-18T00:00:00-04:00","2019-03-19T00:00:00-04:00","2019-03-20T00:00:00-04:00","2019-03-21T00:00:00-04:00","2019-03-22T00:00:00-04:00","2019-03-25T00:00:00-04:00","2019-03-26T00:00:00-04:00","2019-03-27T00:00:00-04:00","2019-03-28T00:00:00-04:00","2019-03-29T00:00:00-04:00","2019-04-01T00:00:00-04:00","2019-04 ...
# ------------

# %% [markdown]
# Modelo 1:Dejando unicamente variables de Volumen y Dividendos, depurando variables correlacionadas y dejando nuevas varibles tecnicas (Ver Codigo de correlacion de Pearson)

# %%
df1= df.loc[:, ['Volume','Close','SMA_10', 'SMA_50', 'SMA_100', 'EMA_10', 'EMA_50', 'EMA_100']] 


#print("The initial DataFrame is:")
#print(df "\n")

#print("The DataFrame depurado de correlacion es:")
#print(df.loc, "\n")

# %%
df1.columns
# Out:
# Index(['Volume', 'Close', 'SMA_10', 'SMA_50', 'SMA_100', 'EMA_10', 'EMA_50',
#        'EMA_100'],
#       dtype='object')

# %%
# Create the lags Nuevo Modelo df_1
def CreateLags(df1,lag_size):
  # inputs: dataframe , size of the lag (int)
  # ouptut: dataframe ( with extra lag column), shift size (int)

  # add lag
  shiftdays = lag_size
  shift = -shiftdays
  df1['Close_lag'] = df1['Close'].shift(shift)
  return df1, shift

# %%
df1
# Out:
#                               Volume       Close      SMA_10      SMA_50  \
# Date
# 2018-10-04 00:00:00-04:00  1714300.0  324.679993  325.407004  309.575401
# 2018-10-05 00:00:00-04:00  1585800.0  316.040009  323.752005  310.158001
# 2018-10-08 00:00:00-04:00  1231300.0  320.239990  323.072003  310.837001
# 2018-10-09 00:00:00-04:00   760500.0  322.640015  322.999005  311.411801
# 2018-10-10 00:00:00-04:00  1416300.0  310.130005  321.845004  311.522802
# ...                              ...         ...         ...         ...
# 2023-05-08 00:00:00-04:00   731500.0  350.500000  348.679004  349.054200
# 2023-05-09 00:00:00-04:00  1035300.0  339.000000  350.185004  348.333201
# 2023-05-10 00:00:00-04:00   619700.0  339.940002  352.116003  347.779801
# 2023-05-11 00:00:00-04:00   664300.0  341.709991  352.012003  347.363201
# 2023-05-12 00:00:00-04:00   779300.0  338.089996  348.951001  346.863201
#
#                             SMA_100      EMA_10      EMA_50     EMA_100
# Date
# 2018-10-04 00:00:00-04:00  297.7788  324.422313  311.598179  297.778800
# 2018-10-05 00:00:00-04:00  298.2361  322.898257  311.772368  298.140408
# 2018-10-08 00:00:00-04:00  298.7152  322.414936  312.104432  298.578024
# 2018-10-09 00:00:00-04:00  299.2599  322.455859  312.517592  299.054499
# 2018-10-10 00:00:00-04:00  299.6595  320.214795  312.423961  299.273816
# ...                             ...         ...         ...         ...
# 2023-05-08 00:00:00-04:00  361.0808  350.001883  352.594560  361.445434
# 2023-05-09 00:00:00-04:00  360.5440  348.001540  352.061440  361.000970
# 2023-05-10 00:00:00-04:00  360.6600  346.535806  351.586090  360.583921
# 2023-05-11 00:00:00-04:00  360.9428  345.658385  351.198792  360.210180
# 2023-05-12 00:00:00-04:00  361.2741  344.282315  350.684721  359.772156
#
# [1159 rows x 8 columns]

# %%
# Split the testing and training data Nuevo Modelo df_1
def SplitData(df1, train_pct, shift):
  # inputs: dataframe , training_pct (float between 0 and 1), size of the lag (int)
  # ouptut: x train dataframe, y train data frame, x test dataframe, y test dataframe, train data frame, test dataframe

  train_pt = int(len(df1)*train_pct)
  
  train = df1.iloc[:train_pt,:]
  test = df1.iloc[train_pt:,:]
  
  x_train = train.iloc[:shift,1:-1]
  y_train = train['Close_lag'][:shift]
  x_test = test.iloc[:shift,1:-1]
  y_test = test['Close'][:shift]

  return x_train, y_train, x_test, y_test, train, test

# %%
# Function to make the plots Modelo Nuevo df_1
def PlotModelResults_Plotly(train, test, pred, ticker, w, h, shift_days,name):
  # inputs: train dataframe, test dataframe, predicted value (list), ticker ('string'), width (int), height (int), shift size (int), name (string)
  # output: None

  # Create lines of the training actual, testing actual, prediction 
  D1 = go.Scatter(x=train.index,y=train['Close'],name = 'Train Actual') # Training actuals
  D2 = go.Scatter(x=test.index[:shift],y=test['Close'],name = 'Test Actual') # Testing actuals
  D3 = go.Scatter(x=test.index[:shift],y=pred,name = 'Our Prediction') # Testing predction

  # Combine in an object  
  line = {'data': [D1,D2,D3],
          'layout': {
              'xaxis' :{'title': 'Date'},
              'yaxis' :{'title': '$'},
              'title' : name + ' - ' + tickerSymbol + ' - ' + str(shift_days)
          }}
  # Send object to a figure 
  fig = go.Figure(line)

  # Show figure
  fig.show()

# %%
# Regreesion Function Nuevmo Modelo df_1

from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_squared_error

def LinearRegression_fnc(x_train, y_train, x_test, y_test, cv=5):
    # Inputs: x train data, y train data, x test data, y test data (all dataframes)
    #        cv: número de folds en la validación cruzada (por defecto, 5)
    # Output: the predicted values for the test data (list)

    lr = LinearRegression()
    lr.fit(x_train, y_train)

    # Realizar la validación cruzada y obtener el rendimiento del modelo
    scores = cross_val_score(lr, x_train, y_train, cv=cv, scoring='r2')
    lr_R2_cv = scores.mean()
    lr_MSE_cv = -scores.mean()

    lr_pred = lr.predict(x_test)
    lr_MSE = mean_squared_error(y_test, lr_pred)
    lr_R2 = lr.score(x_test, y_test)
    print('Linear Regression R2: {}'.format(lr_R2))
    print('Linear Regression MSE: {}'.format(lr_MSE))
    print('Linear Regression R2 (CV): {}'.format(lr_R2_cv))
    print('Coeficiente: ', lr.coef_)
    print('Intercepto: ', lr.intercept_)

    return lr_pred

# %%
# ANN Function Nuevo Modelo df_1

from sklearn.neural_network import MLPRegressor
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error

def ANN_func(x_train, y_train, x_test, y_test):
    # Scaling data
    scaler = StandardScaler()
    scaler.fit(x_train)
    x_train_scaled = scaler.transform(x_train)
    x_test_scaled = scaler.transform(x_test)

    MLP = MLPRegressor(random_state=1, max_iter=1000, hidden_layer_sizes=(100,),
                       activation='identity', learning_rate='adaptive')

    MLP.fit(x_train_scaled, y_train)

    # Perform cross-validation
    MLP_cv_scores = cross_val_score(MLP, x_train_scaled, y_train, cv=5)
    MLP_cv_R2 = MLP_cv_scores.mean()
    MLP_cv_MSE = -MLP_cv_scores.mean()

    MLP_pred = MLP.predict(x_test_scaled)
    MLP_MSE = mean_squared_error(y_test, MLP_pred)
    MLP_R2 = MLP.score(x_test_scaled, y_test)

    print('Multi-layer Perceptron R2 Test: {}'.format(MLP_R2))
    print('Multi-layer Perceptron MSE: {}'.format(MLP_MSE))
    print('Multi-layer Perceptron R2 (CV): {}'.format(MLP_cv_R2))

    return MLP_pred

# %%
## Modelando con cada periodo Nuevo Modelo

# Corregir el código para evitar SettingWithCopyError
for j in shifts: 
  print(str(j) + ' days out:')
  print('------------')
  df1_lag, shift = CreateLags(df1, j)
  df1_lag = CorrectColumnTypes(df1_lag)
  x_train, y_train, x_test, y_test, train, test = SplitData(df1.copy(), train_pct, shift)

  # Linear Regression
  print("Linear Regression")
  lr_pred = LinearRegression_fnc(x_train.copy(), y_train.copy(), x_test.copy(), y_test.copy())
  PlotModelResults_Plotly(train.copy(), test.copy(), lr_pred, tickerSymbol, w, h, j, 'Linear Regression')


  # Artificial Neural Network
  print("ANN")
  MLP_pred = ANN_func(x_train.copy(), y_train.copy(), x_test.copy(), y_test.copy())
  PlotModelResults_Plotly(train.copy(), test.copy(), MLP_pred, tickerSymbol, w, h, j, 'ANN')
  print('------------')
# Out:
# 1 days out:
# ------------
# Linear Regression
# Linear Regression R2: 0.9974565621524707
# Linear Regression MSE: 12.424117357812772
# Linear Regression R2 (CV): 0.957938505171158
# Coeficiente:  [ 9.97017959e-01  6.35889509e-02  6.97915362e-05 -1.38453372e-01
#  -1.07973768e-01  1.40893761e-02  1.69129073e-01]
# Intercepto:  2.489679122765324
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="a46763d2-8cc4-4f74-8c60-5df08d98f030" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a46763d2-8cc4-4f74-8c60-5df08d98f030")) {                    Plotly.newPlot(                        "a46763d2-8cc4-4f74-8c60-5df08d98f030",                        [{"name":"Train Actual","x":["2018-10-04T00:00:00-04:00","2018-10-05T00:00:00-04:00","2018-10-08T00:00:00-04:00","2018-10-09T00:00:00-04:00","2018-10-10T00:00:00-04:00","2018-10-11T00:00:00-04:00","2018-10-12T00:00:00-04:00","2018-10-15T00:00:00-04:00","2018-10-16T00:00:00-04:00","2018-10-17T00:00:00-04:00","2018-10-18T00:00:00-04:00","2018-10-19T00:00:00-04:00","2018-10-22T00:00:00-04:00","2018-10-23T00:00:00-04:00","2018-10-24T00:00:00-04:00","2018-10-25T00:00:00-04:00","2018-10-26T00:00:00-04:00","2018-10-29T00:00:00-04:00","2018-10-30T00:00:00-04:00","2018-10-31T00:00:00-04:00","2018-11-01T00:00:00-04:00","2018-11-02T00:00:00-04:00","2018-11-05T00:00:00-05:00","2018-11-06T00:00:00-05:00","2018-11-07T00:00:00-05:00","2018-11-08T00:00:00-05:00","2018-11-09T00:00:00-05:00","2018-11-12T00:00:00-05:00","2018-11-13T00:00:00-05:00","2018-11-14T00:00:00-05:00","2018-11-15T00:00:00-05:00","2018-11-16T00:00:00-05:00","2018-11-19T00:00:00-05:00","2018-11-20T00:00:00-05:00","2018-11-21T00:00:00-05:00","2018-11-23T00:00:00-05:00","2018-11-26T00:00:00-05:00","2018-11-27T00:00:00-05:00","2018-11-28T00:00:00-05:00","2018-11-29T00:00:00-05:00","2018-11-30T00:00:00-05:00","2018-12-03T00:00:00-05:00","2018-12-04T00:00:00-05:00","2018-12-06T00:00:00-05:00","2018-12-07T00:00:00-05:00","2018-12-10T00:00:00-05:00","2018-12-11T00:00:00-05:00","2018-12-12T00:00:00-05:00","2018-12-13T00:00:00-05:00","2018-12-14T00:00:00-05:00","2018-12-17T00:00:00-05:00","2018-12-18T00:00:00-05:00","2018-12-19T00:00:00-05:00","2018-12-20T00:00:00-05:00","2018-12-21T00:00:00-05:00","2018-12-24T00:00:00-05:00","2018-12-26T00:00:00-05:00","2018-12-27T00:00:00-05:00","2018-12-28T00:00:00-05:00","2018-12-31T00:00:00-05:00","2019-01-02T00:00:00-05:00","2019-01-03T00:00:00-05:00","2019-01-04T00:00:00-05:00","2019-01-07T00:00:00-05:00","2019-01-08T00:00:00-05:00","2019-01-09T00:00:00-05:00","2019-01-10T00:00:00-05:00","2019-01-11T00:00:00-05:00","2019-01-14T00:00:00-05:00","2019-01-15T00:00:00-05:00","2019-01-16T00:00:00-05:00","2019-01-17T00:00:00-05:00","2019-01-18T00:00:00-05:00","2019-01-22T00:00:00-05:00","2019-01-23T00:00:00-05:00","2019-01-24T00:00:00-05:00","2019-01-25T00:00:00-05:00","2019-01-28T00:00:00-05:00","2019-01-29T00:00:00-05:00","2019-01-30T00:00:00-05:00","2019-01-31T00:00:00-05:00","2019-02-01T00:00:00-05:00","2019-02-04T00:00:00-05:00","2019-02-05T00:00:00-05:00","2019-02-06T00:00:00-05:00","2019-02-07T00:00:00-05:00","2019-02-08T00:00:00-05:00","2019-02-11T00:00:00-05:00","2019-02-12T00:00:00-05:00","2019-02-13T00:00:00-05:00","2019-02-14T00:00:00-05:00","2019-02-15T00:00:00-05:00","2019-02-19T00:00:00-05:00","2019-02-20T00:00:00-05:00","2019-02-21T00:00:00-05:00","2019-02-22T00:00:00-05:00","2019-02-25T00:00:00-05:00","2019-02-26T00:00:00-05:00","2019-02-27T00:00:00-05:00","2019-02-28T00:00:00-05:00","2019-03-01T00:00:00-05:00","2019-03-04T00:00:00-05:00","2019-03-05T00:00:00-05:00","2019-03-06T00:00:00-05:00","2019-03-07T00:00:00-05:00","2019-03-08T00:00:00-05:00","2019-03-11T00:00:00-04:00","2019-03-12T00:00:00-04:00","2019-03-13T00:00:00-04:00","2019-03-14T00:00:00-04:00","2019-03-15T00:00:00-04:00","2019-03-18T00:00:00-04:00","2019-03-19T00:00:00-04:00","2019-03-20T00:00:00-04:00","2019-03-21T00:00:00-04:00","2019-03-22T00:00:00-04:00","2019-03-25T00:00:00-04:00","2019-03-26T00:00:00-04:00","2019-03-27T00:00:00-04:00","2019-03-28T00:00:00-04:00","2019-03-29T00:00:00-04:00","2019-04-01T00:00:00-04:00","2019-04 ...
# ANN
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning:
#
# Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning:
#
# Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning:
#
# Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning:
#
# Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning:
#
# Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
# Multi-layer Perceptron R2 Test: 0.9963386485792091
# Multi-layer Perceptron MSE: 17.8848717629521
# Multi-layer Perceptron R2 (CV): 0.9454253511532882
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning:
#
# Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="74a3ce4e-656a-4eb2-b41d-be72534a91ad" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("74a3ce4e-656a-4eb2-b41d-be72534a91ad")) {                    Plotly.newPlot(                        "74a3ce4e-656a-4eb2-b41d-be72534a91ad",                        [{"name":"Train Actual","x":["2018-10-04T00:00:00-04:00","2018-10-05T00:00:00-04:00","2018-10-08T00:00:00-04:00","2018-10-09T00:00:00-04:00","2018-10-10T00:00:00-04:00","2018-10-11T00:00:00-04:00","2018-10-12T00:00:00-04:00","2018-10-15T00:00:00-04:00","2018-10-16T00:00:00-04:00","2018-10-17T00:00:00-04:00","2018-10-18T00:00:00-04:00","2018-10-19T00:00:00-04:00","2018-10-22T00:00:00-04:00","2018-10-23T00:00:00-04:00","2018-10-24T00:00:00-04:00","2018-10-25T00:00:00-04:00","2018-10-26T00:00:00-04:00","2018-10-29T00:00:00-04:00","2018-10-30T00:00:00-04:00","2018-10-31T00:00:00-04:00","2018-11-01T00:00:00-04:00","2018-11-02T00:00:00-04:00","2018-11-05T00:00:00-05:00","2018-11-06T00:00:00-05:00","2018-11-07T00:00:00-05:00","2018-11-08T00:00:00-05:00","2018-11-09T00:00:00-05:00","2018-11-12T00:00:00-05:00","2018-11-13T00:00:00-05:00","2018-11-14T00:00:00-05:00","2018-11-15T00:00:00-05:00","2018-11-16T00:00:00-05:00","2018-11-19T00:00:00-05:00","2018-11-20T00:00:00-05:00","2018-11-21T00:00:00-05:00","2018-11-23T00:00:00-05:00","2018-11-26T00:00:00-05:00","2018-11-27T00:00:00-05:00","2018-11-28T00:00:00-05:00","2018-11-29T00:00:00-05:00","2018-11-30T00:00:00-05:00","2018-12-03T00:00:00-05:00","2018-12-04T00:00:00-05:00","2018-12-06T00:00:00-05:00","2018-12-07T00:00:00-05:00","2018-12-10T00:00:00-05:00","2018-12-11T00:00:00-05:00","2018-12-12T00:00:00-05:00","2018-12-13T00:00:00-05:00","2018-12-14T00:00:00-05:00","2018-12-17T00:00:00-05:00","2018-12-18T00:00:00-05:00","2018-12-19T00:00:00-05:00","2018-12-20T00:00:00-05:00","2018-12-21T00:00:00-05:00","2018-12-24T00:00:00-05:00","2018-12-26T00:00:00-05:00","2018-12-27T00:00:00-05:00","2018-12-28T00:00:00-05:00","2018-12-31T00:00:00-05:00","2019-01-02T00:00:00-05:00","2019-01-03T00:00:00-05:00","2019-01-04T00:00:00-05:00","2019-01-07T00:00:00-05:00","2019-01-08T00:00:00-05:00","2019-01-09T00:00:00-05:00","2019-01-10T00:00:00-05:00","2019-01-11T00:00:00-05:00","2019-01-14T00:00:00-05:00","2019-01-15T00:00:00-05:00","2019-01-16T00:00:00-05:00","2019-01-17T00:00:00-05:00","2019-01-18T00:00:00-05:00","2019-01-22T00:00:00-05:00","2019-01-23T00:00:00-05:00","2019-01-24T00:00:00-05:00","2019-01-25T00:00:00-05:00","2019-01-28T00:00:00-05:00","2019-01-29T00:00:00-05:00","2019-01-30T00:00:00-05:00","2019-01-31T00:00:00-05:00","2019-02-01T00:00:00-05:00","2019-02-04T00:00:00-05:00","2019-02-05T00:00:00-05:00","2019-02-06T00:00:00-05:00","2019-02-07T00:00:00-05:00","2019-02-08T00:00:00-05:00","2019-02-11T00:00:00-05:00","2019-02-12T00:00:00-05:00","2019-02-13T00:00:00-05:00","2019-02-14T00:00:00-05:00","2019-02-15T00:00:00-05:00","2019-02-19T00:00:00-05:00","2019-02-20T00:00:00-05:00","2019-02-21T00:00:00-05:00","2019-02-22T00:00:00-05:00","2019-02-25T00:00:00-05:00","2019-02-26T00:00:00-05:00","2019-02-27T00:00:00-05:00","2019-02-28T00:00:00-05:00","2019-03-01T00:00:00-05:00","2019-03-04T00:00:00-05:00","2019-03-05T00:00:00-05:00","2019-03-06T00:00:00-05:00","2019-03-07T00:00:00-05:00","2019-03-08T00:00:00-05:00","2019-03-11T00:00:00-04:00","2019-03-12T00:00:00-04:00","2019-03-13T00:00:00-04:00","2019-03-14T00:00:00-04:00","2019-03-15T00:00:00-04:00","2019-03-18T00:00:00-04:00","2019-03-19T00:00:00-04:00","2019-03-20T00:00:00-04:00","2019-03-21T00:00:00-04:00","2019-03-22T00:00:00-04:00","2019-03-25T00:00:00-04:00","2019-03-26T00:00:00-04:00","2019-03-27T00:00:00-04:00","2019-03-28T00:00:00-04:00","2019-03-29T00:00:00-04:00","2019-04-01T00:00:00-04:00","2019-04 ...
# ------------
# 5 days out:
# ------------
# Linear Regression
# Linear Regression R2: 0.943844344946565
# Linear Regression MSE: 274.6215845042855
# Linear Regression R2 (CV): 0.8051384261237015
# Coeficiente:  [ 1.10434453  0.45607    -0.12173194 -0.70321774 -0.89404547  0.37491545
#   0.77091927]
# Intercepto:  12.18667455014213
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="5d260c12-917e-4fe2-8c82-220dd28123c8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5d260c12-917e-4fe2-8c82-220dd28123c8")) {                    Plotly.newPlot(                        "5d260c12-917e-4fe2-8c82-220dd28123c8",                        [{"name":"Train Actual","x":["2018-10-04T00:00:00-04:00","2018-10-05T00:00:00-04:00","2018-10-08T00:00:00-04:00","2018-10-09T00:00:00-04:00","2018-10-10T00:00:00-04:00","2018-10-11T00:00:00-04:00","2018-10-12T00:00:00-04:00","2018-10-15T00:00:00-04:00","2018-10-16T00:00:00-04:00","2018-10-17T00:00:00-04:00","2018-10-18T00:00:00-04:00","2018-10-19T00:00:00-04:00","2018-10-22T00:00:00-04:00","2018-10-23T00:00:00-04:00","2018-10-24T00:00:00-04:00","2018-10-25T00:00:00-04:00","2018-10-26T00:00:00-04:00","2018-10-29T00:00:00-04:00","2018-10-30T00:00:00-04:00","2018-10-31T00:00:00-04:00","2018-11-01T00:00:00-04:00","2018-11-02T00:00:00-04:00","2018-11-05T00:00:00-05:00","2018-11-06T00:00:00-05:00","2018-11-07T00:00:00-05:00","2018-11-08T00:00:00-05:00","2018-11-09T00:00:00-05:00","2018-11-12T00:00:00-05:00","2018-11-13T00:00:00-05:00","2018-11-14T00:00:00-05:00","2018-11-15T00:00:00-05:00","2018-11-16T00:00:00-05:00","2018-11-19T00:00:00-05:00","2018-11-20T00:00:00-05:00","2018-11-21T00:00:00-05:00","2018-11-23T00:00:00-05:00","2018-11-26T00:00:00-05:00","2018-11-27T00:00:00-05:00","2018-11-28T00:00:00-05:00","2018-11-29T00:00:00-05:00","2018-11-30T00:00:00-05:00","2018-12-03T00:00:00-05:00","2018-12-04T00:00:00-05:00","2018-12-06T00:00:00-05:00","2018-12-07T00:00:00-05:00","2018-12-10T00:00:00-05:00","2018-12-11T00:00:00-05:00","2018-12-12T00:00:00-05:00","2018-12-13T00:00:00-05:00","2018-12-14T00:00:00-05:00","2018-12-17T00:00:00-05:00","2018-12-18T00:00:00-05:00","2018-12-19T00:00:00-05:00","2018-12-20T00:00:00-05:00","2018-12-21T00:00:00-05:00","2018-12-24T00:00:00-05:00","2018-12-26T00:00:00-05:00","2018-12-27T00:00:00-05:00","2018-12-28T00:00:00-05:00","2018-12-31T00:00:00-05:00","2019-01-02T00:00:00-05:00","2019-01-03T00:00:00-05:00","2019-01-04T00:00:00-05:00","2019-01-07T00:00:00-05:00","2019-01-08T00:00:00-05:00","2019-01-09T00:00:00-05:00","2019-01-10T00:00:00-05:00","2019-01-11T00:00:00-05:00","2019-01-14T00:00:00-05:00","2019-01-15T00:00:00-05:00","2019-01-16T00:00:00-05:00","2019-01-17T00:00:00-05:00","2019-01-18T00:00:00-05:00","2019-01-22T00:00:00-05:00","2019-01-23T00:00:00-05:00","2019-01-24T00:00:00-05:00","2019-01-25T00:00:00-05:00","2019-01-28T00:00:00-05:00","2019-01-29T00:00:00-05:00","2019-01-30T00:00:00-05:00","2019-01-31T00:00:00-05:00","2019-02-01T00:00:00-05:00","2019-02-04T00:00:00-05:00","2019-02-05T00:00:00-05:00","2019-02-06T00:00:00-05:00","2019-02-07T00:00:00-05:00","2019-02-08T00:00:00-05:00","2019-02-11T00:00:00-05:00","2019-02-12T00:00:00-05:00","2019-02-13T00:00:00-05:00","2019-02-14T00:00:00-05:00","2019-02-15T00:00:00-05:00","2019-02-19T00:00:00-05:00","2019-02-20T00:00:00-05:00","2019-02-21T00:00:00-05:00","2019-02-22T00:00:00-05:00","2019-02-25T00:00:00-05:00","2019-02-26T00:00:00-05:00","2019-02-27T00:00:00-05:00","2019-02-28T00:00:00-05:00","2019-03-01T00:00:00-05:00","2019-03-04T00:00:00-05:00","2019-03-05T00:00:00-05:00","2019-03-06T00:00:00-05:00","2019-03-07T00:00:00-05:00","2019-03-08T00:00:00-05:00","2019-03-11T00:00:00-04:00","2019-03-12T00:00:00-04:00","2019-03-13T00:00:00-04:00","2019-03-14T00:00:00-04:00","2019-03-15T00:00:00-04:00","2019-03-18T00:00:00-04:00","2019-03-19T00:00:00-04:00","2019-03-20T00:00:00-04:00","2019-03-21T00:00:00-04:00","2019-03-22T00:00:00-04:00","2019-03-25T00:00:00-04:00","2019-03-26T00:00:00-04:00","2019-03-27T00:00:00-04:00","2019-03-28T00:00:00-04:00","2019-03-29T00:00:00-04:00","2019-04-01T00:00:00-04:00","2019-04 ...
# ANN
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning:
#
# Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning:
#
# Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning:
#
# Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning:
#
# Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning:
#
# Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
# Multi-layer Perceptron R2 Test: 0.9913870907518776
# Multi-layer Perceptron MSE: 42.120259885853024
# Multi-layer Perceptron R2 (CV): 0.8193696380711977
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning:
#
# Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="2cde0154-11dc-4905-8cdd-a6dadb7b6f89" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2cde0154-11dc-4905-8cdd-a6dadb7b6f89")) {                    Plotly.newPlot(                        "2cde0154-11dc-4905-8cdd-a6dadb7b6f89",                        [{"name":"Train Actual","x":["2018-10-04T00:00:00-04:00","2018-10-05T00:00:00-04:00","2018-10-08T00:00:00-04:00","2018-10-09T00:00:00-04:00","2018-10-10T00:00:00-04:00","2018-10-11T00:00:00-04:00","2018-10-12T00:00:00-04:00","2018-10-15T00:00:00-04:00","2018-10-16T00:00:00-04:00","2018-10-17T00:00:00-04:00","2018-10-18T00:00:00-04:00","2018-10-19T00:00:00-04:00","2018-10-22T00:00:00-04:00","2018-10-23T00:00:00-04:00","2018-10-24T00:00:00-04:00","2018-10-25T00:00:00-04:00","2018-10-26T00:00:00-04:00","2018-10-29T00:00:00-04:00","2018-10-30T00:00:00-04:00","2018-10-31T00:00:00-04:00","2018-11-01T00:00:00-04:00","2018-11-02T00:00:00-04:00","2018-11-05T00:00:00-05:00","2018-11-06T00:00:00-05:00","2018-11-07T00:00:00-05:00","2018-11-08T00:00:00-05:00","2018-11-09T00:00:00-05:00","2018-11-12T00:00:00-05:00","2018-11-13T00:00:00-05:00","2018-11-14T00:00:00-05:00","2018-11-15T00:00:00-05:00","2018-11-16T00:00:00-05:00","2018-11-19T00:00:00-05:00","2018-11-20T00:00:00-05:00","2018-11-21T00:00:00-05:00","2018-11-23T00:00:00-05:00","2018-11-26T00:00:00-05:00","2018-11-27T00:00:00-05:00","2018-11-28T00:00:00-05:00","2018-11-29T00:00:00-05:00","2018-11-30T00:00:00-05:00","2018-12-03T00:00:00-05:00","2018-12-04T00:00:00-05:00","2018-12-06T00:00:00-05:00","2018-12-07T00:00:00-05:00","2018-12-10T00:00:00-05:00","2018-12-11T00:00:00-05:00","2018-12-12T00:00:00-05:00","2018-12-13T00:00:00-05:00","2018-12-14T00:00:00-05:00","2018-12-17T00:00:00-05:00","2018-12-18T00:00:00-05:00","2018-12-19T00:00:00-05:00","2018-12-20T00:00:00-05:00","2018-12-21T00:00:00-05:00","2018-12-24T00:00:00-05:00","2018-12-26T00:00:00-05:00","2018-12-27T00:00:00-05:00","2018-12-28T00:00:00-05:00","2018-12-31T00:00:00-05:00","2019-01-02T00:00:00-05:00","2019-01-03T00:00:00-05:00","2019-01-04T00:00:00-05:00","2019-01-07T00:00:00-05:00","2019-01-08T00:00:00-05:00","2019-01-09T00:00:00-05:00","2019-01-10T00:00:00-05:00","2019-01-11T00:00:00-05:00","2019-01-14T00:00:00-05:00","2019-01-15T00:00:00-05:00","2019-01-16T00:00:00-05:00","2019-01-17T00:00:00-05:00","2019-01-18T00:00:00-05:00","2019-01-22T00:00:00-05:00","2019-01-23T00:00:00-05:00","2019-01-24T00:00:00-05:00","2019-01-25T00:00:00-05:00","2019-01-28T00:00:00-05:00","2019-01-29T00:00:00-05:00","2019-01-30T00:00:00-05:00","2019-01-31T00:00:00-05:00","2019-02-01T00:00:00-05:00","2019-02-04T00:00:00-05:00","2019-02-05T00:00:00-05:00","2019-02-06T00:00:00-05:00","2019-02-07T00:00:00-05:00","2019-02-08T00:00:00-05:00","2019-02-11T00:00:00-05:00","2019-02-12T00:00:00-05:00","2019-02-13T00:00:00-05:00","2019-02-14T00:00:00-05:00","2019-02-15T00:00:00-05:00","2019-02-19T00:00:00-05:00","2019-02-20T00:00:00-05:00","2019-02-21T00:00:00-05:00","2019-02-22T00:00:00-05:00","2019-02-25T00:00:00-05:00","2019-02-26T00:00:00-05:00","2019-02-27T00:00:00-05:00","2019-02-28T00:00:00-05:00","2019-03-01T00:00:00-05:00","2019-03-04T00:00:00-05:00","2019-03-05T00:00:00-05:00","2019-03-06T00:00:00-05:00","2019-03-07T00:00:00-05:00","2019-03-08T00:00:00-05:00","2019-03-11T00:00:00-04:00","2019-03-12T00:00:00-04:00","2019-03-13T00:00:00-04:00","2019-03-14T00:00:00-04:00","2019-03-15T00:00:00-04:00","2019-03-18T00:00:00-04:00","2019-03-19T00:00:00-04:00","2019-03-20T00:00:00-04:00","2019-03-21T00:00:00-04:00","2019-03-22T00:00:00-04:00","2019-03-25T00:00:00-04:00","2019-03-26T00:00:00-04:00","2019-03-27T00:00:00-04:00","2019-03-28T00:00:00-04:00","2019-03-29T00:00:00-04:00","2019-04-01T00:00:00-04:00","2019-04 ...
# ------------
# 10 days out:
# ------------
# Linear Regression
# Linear Regression R2: 0.783935182703193
# Linear Regression MSE: 1063.8933865855677
# Linear Regression R2 (CV): 0.5784446816338753
# Coeficiente:  [ 0.98658498 -0.10566093 -0.22839348 -1.32386814 -0.3902832   0.50534609
#   1.53141826]
# Intercepto:  23.989391026673786
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="4aecbd96-f650-407c-97bd-c73c17256d45" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4aecbd96-f650-407c-97bd-c73c17256d45")) {                    Plotly.newPlot(                        "4aecbd96-f650-407c-97bd-c73c17256d45",                        [{"name":"Train Actual","x":["2018-10-04T00:00:00-04:00","2018-10-05T00:00:00-04:00","2018-10-08T00:00:00-04:00","2018-10-09T00:00:00-04:00","2018-10-10T00:00:00-04:00","2018-10-11T00:00:00-04:00","2018-10-12T00:00:00-04:00","2018-10-15T00:00:00-04:00","2018-10-16T00:00:00-04:00","2018-10-17T00:00:00-04:00","2018-10-18T00:00:00-04:00","2018-10-19T00:00:00-04:00","2018-10-22T00:00:00-04:00","2018-10-23T00:00:00-04:00","2018-10-24T00:00:00-04:00","2018-10-25T00:00:00-04:00","2018-10-26T00:00:00-04:00","2018-10-29T00:00:00-04:00","2018-10-30T00:00:00-04:00","2018-10-31T00:00:00-04:00","2018-11-01T00:00:00-04:00","2018-11-02T00:00:00-04:00","2018-11-05T00:00:00-05:00","2018-11-06T00:00:00-05:00","2018-11-07T00:00:00-05:00","2018-11-08T00:00:00-05:00","2018-11-09T00:00:00-05:00","2018-11-12T00:00:00-05:00","2018-11-13T00:00:00-05:00","2018-11-14T00:00:00-05:00","2018-11-15T00:00:00-05:00","2018-11-16T00:00:00-05:00","2018-11-19T00:00:00-05:00","2018-11-20T00:00:00-05:00","2018-11-21T00:00:00-05:00","2018-11-23T00:00:00-05:00","2018-11-26T00:00:00-05:00","2018-11-27T00:00:00-05:00","2018-11-28T00:00:00-05:00","2018-11-29T00:00:00-05:00","2018-11-30T00:00:00-05:00","2018-12-03T00:00:00-05:00","2018-12-04T00:00:00-05:00","2018-12-06T00:00:00-05:00","2018-12-07T00:00:00-05:00","2018-12-10T00:00:00-05:00","2018-12-11T00:00:00-05:00","2018-12-12T00:00:00-05:00","2018-12-13T00:00:00-05:00","2018-12-14T00:00:00-05:00","2018-12-17T00:00:00-05:00","2018-12-18T00:00:00-05:00","2018-12-19T00:00:00-05:00","2018-12-20T00:00:00-05:00","2018-12-21T00:00:00-05:00","2018-12-24T00:00:00-05:00","2018-12-26T00:00:00-05:00","2018-12-27T00:00:00-05:00","2018-12-28T00:00:00-05:00","2018-12-31T00:00:00-05:00","2019-01-02T00:00:00-05:00","2019-01-03T00:00:00-05:00","2019-01-04T00:00:00-05:00","2019-01-07T00:00:00-05:00","2019-01-08T00:00:00-05:00","2019-01-09T00:00:00-05:00","2019-01-10T00:00:00-05:00","2019-01-11T00:00:00-05:00","2019-01-14T00:00:00-05:00","2019-01-15T00:00:00-05:00","2019-01-16T00:00:00-05:00","2019-01-17T00:00:00-05:00","2019-01-18T00:00:00-05:00","2019-01-22T00:00:00-05:00","2019-01-23T00:00:00-05:00","2019-01-24T00:00:00-05:00","2019-01-25T00:00:00-05:00","2019-01-28T00:00:00-05:00","2019-01-29T00:00:00-05:00","2019-01-30T00:00:00-05:00","2019-01-31T00:00:00-05:00","2019-02-01T00:00:00-05:00","2019-02-04T00:00:00-05:00","2019-02-05T00:00:00-05:00","2019-02-06T00:00:00-05:00","2019-02-07T00:00:00-05:00","2019-02-08T00:00:00-05:00","2019-02-11T00:00:00-05:00","2019-02-12T00:00:00-05:00","2019-02-13T00:00:00-05:00","2019-02-14T00:00:00-05:00","2019-02-15T00:00:00-05:00","2019-02-19T00:00:00-05:00","2019-02-20T00:00:00-05:00","2019-02-21T00:00:00-05:00","2019-02-22T00:00:00-05:00","2019-02-25T00:00:00-05:00","2019-02-26T00:00:00-05:00","2019-02-27T00:00:00-05:00","2019-02-28T00:00:00-05:00","2019-03-01T00:00:00-05:00","2019-03-04T00:00:00-05:00","2019-03-05T00:00:00-05:00","2019-03-06T00:00:00-05:00","2019-03-07T00:00:00-05:00","2019-03-08T00:00:00-05:00","2019-03-11T00:00:00-04:00","2019-03-12T00:00:00-04:00","2019-03-13T00:00:00-04:00","2019-03-14T00:00:00-04:00","2019-03-15T00:00:00-04:00","2019-03-18T00:00:00-04:00","2019-03-19T00:00:00-04:00","2019-03-20T00:00:00-04:00","2019-03-21T00:00:00-04:00","2019-03-22T00:00:00-04:00","2019-03-25T00:00:00-04:00","2019-03-26T00:00:00-04:00","2019-03-27T00:00:00-04:00","2019-03-28T00:00:00-04:00","2019-03-29T00:00:00-04:00","2019-04-01T00:00:00-04:00","2019-04 ...
# ANN
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning:
#
# Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning:
#
# Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning:
#
# Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning:
#
# Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
# Multi-layer Perceptron R2 Test: 0.9820681374187932
# Multi-layer Perceptron MSE: 88.29568019443165
# Multi-layer Perceptron R2 (CV): 0.6480662246869846
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning:
#
# Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="d4a9f4be-f0d8-4abe-9f70-f09559842bff" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d4a9f4be-f0d8-4abe-9f70-f09559842bff")) {                    Plotly.newPlot(                        "d4a9f4be-f0d8-4abe-9f70-f09559842bff",                        [{"name":"Train Actual","x":["2018-10-04T00:00:00-04:00","2018-10-05T00:00:00-04:00","2018-10-08T00:00:00-04:00","2018-10-09T00:00:00-04:00","2018-10-10T00:00:00-04:00","2018-10-11T00:00:00-04:00","2018-10-12T00:00:00-04:00","2018-10-15T00:00:00-04:00","2018-10-16T00:00:00-04:00","2018-10-17T00:00:00-04:00","2018-10-18T00:00:00-04:00","2018-10-19T00:00:00-04:00","2018-10-22T00:00:00-04:00","2018-10-23T00:00:00-04:00","2018-10-24T00:00:00-04:00","2018-10-25T00:00:00-04:00","2018-10-26T00:00:00-04:00","2018-10-29T00:00:00-04:00","2018-10-30T00:00:00-04:00","2018-10-31T00:00:00-04:00","2018-11-01T00:00:00-04:00","2018-11-02T00:00:00-04:00","2018-11-05T00:00:00-05:00","2018-11-06T00:00:00-05:00","2018-11-07T00:00:00-05:00","2018-11-08T00:00:00-05:00","2018-11-09T00:00:00-05:00","2018-11-12T00:00:00-05:00","2018-11-13T00:00:00-05:00","2018-11-14T00:00:00-05:00","2018-11-15T00:00:00-05:00","2018-11-16T00:00:00-05:00","2018-11-19T00:00:00-05:00","2018-11-20T00:00:00-05:00","2018-11-21T00:00:00-05:00","2018-11-23T00:00:00-05:00","2018-11-26T00:00:00-05:00","2018-11-27T00:00:00-05:00","2018-11-28T00:00:00-05:00","2018-11-29T00:00:00-05:00","2018-11-30T00:00:00-05:00","2018-12-03T00:00:00-05:00","2018-12-04T00:00:00-05:00","2018-12-06T00:00:00-05:00","2018-12-07T00:00:00-05:00","2018-12-10T00:00:00-05:00","2018-12-11T00:00:00-05:00","2018-12-12T00:00:00-05:00","2018-12-13T00:00:00-05:00","2018-12-14T00:00:00-05:00","2018-12-17T00:00:00-05:00","2018-12-18T00:00:00-05:00","2018-12-19T00:00:00-05:00","2018-12-20T00:00:00-05:00","2018-12-21T00:00:00-05:00","2018-12-24T00:00:00-05:00","2018-12-26T00:00:00-05:00","2018-12-27T00:00:00-05:00","2018-12-28T00:00:00-05:00","2018-12-31T00:00:00-05:00","2019-01-02T00:00:00-05:00","2019-01-03T00:00:00-05:00","2019-01-04T00:00:00-05:00","2019-01-07T00:00:00-05:00","2019-01-08T00:00:00-05:00","2019-01-09T00:00:00-05:00","2019-01-10T00:00:00-05:00","2019-01-11T00:00:00-05:00","2019-01-14T00:00:00-05:00","2019-01-15T00:00:00-05:00","2019-01-16T00:00:00-05:00","2019-01-17T00:00:00-05:00","2019-01-18T00:00:00-05:00","2019-01-22T00:00:00-05:00","2019-01-23T00:00:00-05:00","2019-01-24T00:00:00-05:00","2019-01-25T00:00:00-05:00","2019-01-28T00:00:00-05:00","2019-01-29T00:00:00-05:00","2019-01-30T00:00:00-05:00","2019-01-31T00:00:00-05:00","2019-02-01T00:00:00-05:00","2019-02-04T00:00:00-05:00","2019-02-05T00:00:00-05:00","2019-02-06T00:00:00-05:00","2019-02-07T00:00:00-05:00","2019-02-08T00:00:00-05:00","2019-02-11T00:00:00-05:00","2019-02-12T00:00:00-05:00","2019-02-13T00:00:00-05:00","2019-02-14T00:00:00-05:00","2019-02-15T00:00:00-05:00","2019-02-19T00:00:00-05:00","2019-02-20T00:00:00-05:00","2019-02-21T00:00:00-05:00","2019-02-22T00:00:00-05:00","2019-02-25T00:00:00-05:00","2019-02-26T00:00:00-05:00","2019-02-27T00:00:00-05:00","2019-02-28T00:00:00-05:00","2019-03-01T00:00:00-05:00","2019-03-04T00:00:00-05:00","2019-03-05T00:00:00-05:00","2019-03-06T00:00:00-05:00","2019-03-07T00:00:00-05:00","2019-03-08T00:00:00-05:00","2019-03-11T00:00:00-04:00","2019-03-12T00:00:00-04:00","2019-03-13T00:00:00-04:00","2019-03-14T00:00:00-04:00","2019-03-15T00:00:00-04:00","2019-03-18T00:00:00-04:00","2019-03-19T00:00:00-04:00","2019-03-20T00:00:00-04:00","2019-03-21T00:00:00-04:00","2019-03-22T00:00:00-04:00","2019-03-25T00:00:00-04:00","2019-03-26T00:00:00-04:00","2019-03-27T00:00:00-04:00","2019-03-28T00:00:00-04:00","2019-03-29T00:00:00-04:00","2019-04-01T00:00:00-04:00","2019-04 ...
# ------------
# 30 days out:
# ------------
# Linear Regression
# Linear Regression R2: -2.5924281019504467
# Linear Regression MSE: 17711.83136788836
# Linear Regression R2 (CV): -0.31082751868396075
# Coeficiente:  [ 4.65616294e-01  3.38575406e-03  6.53790518e-01 -3.81243187e+00
#   5.14533394e-01 -3.27593577e+00  6.40263567e+00]
# Intercepto:  71.50760334758013
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="3dcaa9f0-5e38-4e18-a19e-2e5747bf00db" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3dcaa9f0-5e38-4e18-a19e-2e5747bf00db")) {                    Plotly.newPlot(                        "3dcaa9f0-5e38-4e18-a19e-2e5747bf00db",                        [{"name":"Train Actual","x":["2018-10-04T00:00:00-04:00","2018-10-05T00:00:00-04:00","2018-10-08T00:00:00-04:00","2018-10-09T00:00:00-04:00","2018-10-10T00:00:00-04:00","2018-10-11T00:00:00-04:00","2018-10-12T00:00:00-04:00","2018-10-15T00:00:00-04:00","2018-10-16T00:00:00-04:00","2018-10-17T00:00:00-04:00","2018-10-18T00:00:00-04:00","2018-10-19T00:00:00-04:00","2018-10-22T00:00:00-04:00","2018-10-23T00:00:00-04:00","2018-10-24T00:00:00-04:00","2018-10-25T00:00:00-04:00","2018-10-26T00:00:00-04:00","2018-10-29T00:00:00-04:00","2018-10-30T00:00:00-04:00","2018-10-31T00:00:00-04:00","2018-11-01T00:00:00-04:00","2018-11-02T00:00:00-04:00","2018-11-05T00:00:00-05:00","2018-11-06T00:00:00-05:00","2018-11-07T00:00:00-05:00","2018-11-08T00:00:00-05:00","2018-11-09T00:00:00-05:00","2018-11-12T00:00:00-05:00","2018-11-13T00:00:00-05:00","2018-11-14T00:00:00-05:00","2018-11-15T00:00:00-05:00","2018-11-16T00:00:00-05:00","2018-11-19T00:00:00-05:00","2018-11-20T00:00:00-05:00","2018-11-21T00:00:00-05:00","2018-11-23T00:00:00-05:00","2018-11-26T00:00:00-05:00","2018-11-27T00:00:00-05:00","2018-11-28T00:00:00-05:00","2018-11-29T00:00:00-05:00","2018-11-30T00:00:00-05:00","2018-12-03T00:00:00-05:00","2018-12-04T00:00:00-05:00","2018-12-06T00:00:00-05:00","2018-12-07T00:00:00-05:00","2018-12-10T00:00:00-05:00","2018-12-11T00:00:00-05:00","2018-12-12T00:00:00-05:00","2018-12-13T00:00:00-05:00","2018-12-14T00:00:00-05:00","2018-12-17T00:00:00-05:00","2018-12-18T00:00:00-05:00","2018-12-19T00:00:00-05:00","2018-12-20T00:00:00-05:00","2018-12-21T00:00:00-05:00","2018-12-24T00:00:00-05:00","2018-12-26T00:00:00-05:00","2018-12-27T00:00:00-05:00","2018-12-28T00:00:00-05:00","2018-12-31T00:00:00-05:00","2019-01-02T00:00:00-05:00","2019-01-03T00:00:00-05:00","2019-01-04T00:00:00-05:00","2019-01-07T00:00:00-05:00","2019-01-08T00:00:00-05:00","2019-01-09T00:00:00-05:00","2019-01-10T00:00:00-05:00","2019-01-11T00:00:00-05:00","2019-01-14T00:00:00-05:00","2019-01-15T00:00:00-05:00","2019-01-16T00:00:00-05:00","2019-01-17T00:00:00-05:00","2019-01-18T00:00:00-05:00","2019-01-22T00:00:00-05:00","2019-01-23T00:00:00-05:00","2019-01-24T00:00:00-05:00","2019-01-25T00:00:00-05:00","2019-01-28T00:00:00-05:00","2019-01-29T00:00:00-05:00","2019-01-30T00:00:00-05:00","2019-01-31T00:00:00-05:00","2019-02-01T00:00:00-05:00","2019-02-04T00:00:00-05:00","2019-02-05T00:00:00-05:00","2019-02-06T00:00:00-05:00","2019-02-07T00:00:00-05:00","2019-02-08T00:00:00-05:00","2019-02-11T00:00:00-05:00","2019-02-12T00:00:00-05:00","2019-02-13T00:00:00-05:00","2019-02-14T00:00:00-05:00","2019-02-15T00:00:00-05:00","2019-02-19T00:00:00-05:00","2019-02-20T00:00:00-05:00","2019-02-21T00:00:00-05:00","2019-02-22T00:00:00-05:00","2019-02-25T00:00:00-05:00","2019-02-26T00:00:00-05:00","2019-02-27T00:00:00-05:00","2019-02-28T00:00:00-05:00","2019-03-01T00:00:00-05:00","2019-03-04T00:00:00-05:00","2019-03-05T00:00:00-05:00","2019-03-06T00:00:00-05:00","2019-03-07T00:00:00-05:00","2019-03-08T00:00:00-05:00","2019-03-11T00:00:00-04:00","2019-03-12T00:00:00-04:00","2019-03-13T00:00:00-04:00","2019-03-14T00:00:00-04:00","2019-03-15T00:00:00-04:00","2019-03-18T00:00:00-04:00","2019-03-19T00:00:00-04:00","2019-03-20T00:00:00-04:00","2019-03-21T00:00:00-04:00","2019-03-22T00:00:00-04:00","2019-03-25T00:00:00-04:00","2019-03-26T00:00:00-04:00","2019-03-27T00:00:00-04:00","2019-03-28T00:00:00-04:00","2019-03-29T00:00:00-04:00","2019-04-01T00:00:00-04:00","2019-04 ...
# ANN
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning:
#
# Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning:
#
# Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning:
#
# Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
# Multi-layer Perceptron R2 Test: 0.9102382602442616
# Multi-layer Perceptron MSE: 442.55438180620524
# Multi-layer Perceptron R2 (CV): -0.017253299380854938
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning:
#
# Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="a86c1eaf-a147-4e83-80f8-20e77f5c3e9d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a86c1eaf-a147-4e83-80f8-20e77f5c3e9d")) {                    Plotly.newPlot(                        "a86c1eaf-a147-4e83-80f8-20e77f5c3e9d",                        [{"name":"Train Actual","x":["2018-10-04T00:00:00-04:00","2018-10-05T00:00:00-04:00","2018-10-08T00:00:00-04:00","2018-10-09T00:00:00-04:00","2018-10-10T00:00:00-04:00","2018-10-11T00:00:00-04:00","2018-10-12T00:00:00-04:00","2018-10-15T00:00:00-04:00","2018-10-16T00:00:00-04:00","2018-10-17T00:00:00-04:00","2018-10-18T00:00:00-04:00","2018-10-19T00:00:00-04:00","2018-10-22T00:00:00-04:00","2018-10-23T00:00:00-04:00","2018-10-24T00:00:00-04:00","2018-10-25T00:00:00-04:00","2018-10-26T00:00:00-04:00","2018-10-29T00:00:00-04:00","2018-10-30T00:00:00-04:00","2018-10-31T00:00:00-04:00","2018-11-01T00:00:00-04:00","2018-11-02T00:00:00-04:00","2018-11-05T00:00:00-05:00","2018-11-06T00:00:00-05:00","2018-11-07T00:00:00-05:00","2018-11-08T00:00:00-05:00","2018-11-09T00:00:00-05:00","2018-11-12T00:00:00-05:00","2018-11-13T00:00:00-05:00","2018-11-14T00:00:00-05:00","2018-11-15T00:00:00-05:00","2018-11-16T00:00:00-05:00","2018-11-19T00:00:00-05:00","2018-11-20T00:00:00-05:00","2018-11-21T00:00:00-05:00","2018-11-23T00:00:00-05:00","2018-11-26T00:00:00-05:00","2018-11-27T00:00:00-05:00","2018-11-28T00:00:00-05:00","2018-11-29T00:00:00-05:00","2018-11-30T00:00:00-05:00","2018-12-03T00:00:00-05:00","2018-12-04T00:00:00-05:00","2018-12-06T00:00:00-05:00","2018-12-07T00:00:00-05:00","2018-12-10T00:00:00-05:00","2018-12-11T00:00:00-05:00","2018-12-12T00:00:00-05:00","2018-12-13T00:00:00-05:00","2018-12-14T00:00:00-05:00","2018-12-17T00:00:00-05:00","2018-12-18T00:00:00-05:00","2018-12-19T00:00:00-05:00","2018-12-20T00:00:00-05:00","2018-12-21T00:00:00-05:00","2018-12-24T00:00:00-05:00","2018-12-26T00:00:00-05:00","2018-12-27T00:00:00-05:00","2018-12-28T00:00:00-05:00","2018-12-31T00:00:00-05:00","2019-01-02T00:00:00-05:00","2019-01-03T00:00:00-05:00","2019-01-04T00:00:00-05:00","2019-01-07T00:00:00-05:00","2019-01-08T00:00:00-05:00","2019-01-09T00:00:00-05:00","2019-01-10T00:00:00-05:00","2019-01-11T00:00:00-05:00","2019-01-14T00:00:00-05:00","2019-01-15T00:00:00-05:00","2019-01-16T00:00:00-05:00","2019-01-17T00:00:00-05:00","2019-01-18T00:00:00-05:00","2019-01-22T00:00:00-05:00","2019-01-23T00:00:00-05:00","2019-01-24T00:00:00-05:00","2019-01-25T00:00:00-05:00","2019-01-28T00:00:00-05:00","2019-01-29T00:00:00-05:00","2019-01-30T00:00:00-05:00","2019-01-31T00:00:00-05:00","2019-02-01T00:00:00-05:00","2019-02-04T00:00:00-05:00","2019-02-05T00:00:00-05:00","2019-02-06T00:00:00-05:00","2019-02-07T00:00:00-05:00","2019-02-08T00:00:00-05:00","2019-02-11T00:00:00-05:00","2019-02-12T00:00:00-05:00","2019-02-13T00:00:00-05:00","2019-02-14T00:00:00-05:00","2019-02-15T00:00:00-05:00","2019-02-19T00:00:00-05:00","2019-02-20T00:00:00-05:00","2019-02-21T00:00:00-05:00","2019-02-22T00:00:00-05:00","2019-02-25T00:00:00-05:00","2019-02-26T00:00:00-05:00","2019-02-27T00:00:00-05:00","2019-02-28T00:00:00-05:00","2019-03-01T00:00:00-05:00","2019-03-04T00:00:00-05:00","2019-03-05T00:00:00-05:00","2019-03-06T00:00:00-05:00","2019-03-07T00:00:00-05:00","2019-03-08T00:00:00-05:00","2019-03-11T00:00:00-04:00","2019-03-12T00:00:00-04:00","2019-03-13T00:00:00-04:00","2019-03-14T00:00:00-04:00","2019-03-15T00:00:00-04:00","2019-03-18T00:00:00-04:00","2019-03-19T00:00:00-04:00","2019-03-20T00:00:00-04:00","2019-03-21T00:00:00-04:00","2019-03-22T00:00:00-04:00","2019-03-25T00:00:00-04:00","2019-03-26T00:00:00-04:00","2019-03-27T00:00:00-04:00","2019-03-28T00:00:00-04:00","2019-03-29T00:00:00-04:00","2019-04-01T00:00:00-04:00","2019-04 ...
# ------------

# %%
from datetime import datetime, timedelta

# Obtener la fecha de mañana
tomorrow = datetime.now() + timedelta(days=1)

# Ajustar el conjunto de datos para incluir el día de mañana
df1_lag_tomorrow, shift = CreateLags(df1, 1)  # Utiliza una ventana de 1 día para crear los retrasos
df1_lag_tomorrow = CorrectColumnTypes(df1_lag_tomorrow)

# Obtener los datos de entrenamiento y prueba para el día de mañana
x_train_tomorrow, y_train_tomorrow, x_test_tomorrow, y_test_tomorrow, _, _ = SplitData(df1_lag_tomorrow.copy(), train_pct, shift)

# Realizar la predicción para el día de mañana utilizando el modelo de regresión lineal
lr_pred_tomorrow = LinearRegression_fnc(x_train_tomorrow.copy(), y_train_tomorrow.copy(), x_test_tomorrow.copy(), y_test_tomorrow.copy())

# Imprimir la predicción para el día de mañana
print('Predicción para el día de mañana:')
print(lr_pred_tomorrow)
# Out:
# Linear Regression R2: 0.9974565621524707
# Linear Regression MSE: 12.424117357812772
# Linear Regression R2 (CV): 0.957938505171158
# Coeficiente:  [ 9.97017959e-01  6.35889509e-02  6.97915362e-05 -1.38453372e-01
#  -1.07973768e-01  1.40893761e-02  1.69129073e-01]
# Intercepto:  2.489679122765324
# Predicción para el día de mañana:
# [579.23655803 567.90624616 576.85337089 562.43737615 561.88168779
#  560.9324504  567.8775705  574.83545443 572.55484928 548.20041294
#  564.24840408 564.5731075  559.39058666 563.87718388 555.24705186
#  560.4036214  562.67929336 551.97237161 565.09462822 558.16502792
#  536.62417561 560.71976548 539.17564553 522.57055174 515.23197233
#  511.01452993 491.30038419 486.63686272 466.44468869 434.01332773
#  438.31924446 431.39414774 453.68587546 461.11144457 464.23267499
#  467.6810266  471.8656849  451.97062208 468.68043924 474.8016612
#  466.8814067  475.69898337 473.06197737 478.02429819 482.3485748
#  476.96169891 482.18751056 490.70628451 505.62797483 512.4220501
#  509.30720927 497.83543968 500.69240352 493.65791706 487.47125804
#  485.49152289 490.95046235 485.343305   477.29951227 457.76233853
#  455.32403698 452.42704967 419.21107325 445.6305322  441.06212446
#  451.55293915 458.09592685 465.70519152 466.66867034 459.33534827
#  466.06353597 470.67443909 483.08729422 483.34925939 473.96514994
#  467.91853647 466.21783584 456.28519887 470.94172752 468.56961929
#  471.66388502 479.38457062 476.68459808 485.37260373 485.52876311
#  494.94801802 487.99418829 481.51867436 481.64936693 478.72818814
#  439.01801649 435.92657357 430.72017732 441.80102174 456.09645835
#  463.01032137 466.23708649 467.0801567  455.50058673 465.49979619
#  469.07206778 480.9597013  483.83057021 485.76867482 468.46101383
#  461.48103287 458.08228759 442.51489298 436.47108062 433.8251272
#  443.1962464  430.52829548 423.12584796 414.41006009 417.53465525
#  425.12572491 412.02758527 402.09650959 407.7172798  401.21021246
#  411.02973459 411.50792484 392.16128574 390.51575999 381.56121184
#  383.10607451 377.69249701 368.63617085 358.81646292 339.96016301
#  327.77665176 312.43078133 313.14809003 327.04597028 318.41528782
#  309.04602349 325.51731228 333.28495948 333.63626681 328.13717243
#  316.75071332 322.50860228 312.76769851 310.62947078 329.9935391
#  327.27917041 335.37281503 332.33715053 327.99769045 331.34281677
#  333.56770368 340.07229043 349.54740653 347.67264335 357.79966555
#  370.46379789 369.64117411 359.06234564 349.50822543 346.66354077
#  351.28663621 355.71189353 356.96491734 352.19900369 375.08921003
#  395.73302388 388.85675632 392.94424455 389.78337813 385.30915299
#  375.6836748  370.60573298 387.20023443 391.98006431 391.86273819
#  386.19815811 387.00745495 392.90844603 390.7888813  394.31893954
#  389.59156388 373.40826295 377.30195247 376.86668895 383.15799218
#  387.03442274 395.25707042 331.76054342 317.52909827 309.57513498
#  311.02631476 314.31186674 326.21335604 328.57254544 338.24844783
#  336.79402839 335.97826623 342.53313815 342.76952192 345.3819231
#  357.7951938  365.21564788 371.44878975 370.93210072 378.3028012
#  382.05381839 389.04837792 392.0094021  391.93557512 385.62923871
#  388.06864341 399.89164017 399.76128331 395.85330133 407.47143155
#  413.98696658 398.14622427 394.78966577 388.35591429 402.70860554
#  416.1433727  410.17408317 408.45915305 406.54149772 407.20232778
#  397.74729913 400.99001839 404.21862229 404.29865272 407.69567155
#  404.33828626 399.54281912 382.01142898 386.76872646 387.31079437
#  378.9830212  379.2321644  371.84904286 366.82067207 367.29048647
#  373.9573631  372.91434852 361.7127421  357.72399452 346.95744125
#  333.64869785 339.40408211 340.24350118 345.89498794 350.18705419
#  353.44781338 351.93981355 355.26735499 344.78697196 345.13044829
#  346.97657756 351.35188958 348.53805688 352.59615769 351.82621368
#  360.14924296 358.60852305 350.48996817 355.42163816 352.59948598
#  356.2073834  360.7482605  345.69310778 350.06093436 344.0338887
#  348.64686236 345.74755572 346.11366553 338.5296171  335.33024885
#  333.48588886 326.65325483 323.4752934  345.32662289 370.79278134
#  368.30609692 358.93301656 358.52884926 350.52412198 352.68339422
#  352.45585891 341.29349014 342.41840885 344.16339385]
